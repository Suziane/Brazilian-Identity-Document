# %%
# !sudo apt-get install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.2.1)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
# !tesseract --version
# !tesseract --help-psm
# Out:
# tesseract 4.1.1
#  leptonica-1.82.0
#   libgif 5.1.9 : libjpeg 8d (libjpeg-turbo 2.1.1) : libpng 1.6.37 : libtiff 4.3.0 : zlib 1.2.11 : libwebp 1.2.2 : libopenjp2 2.4.0
#  Found AVX2
#  Found AVX
#  Found FMA
#  Found SSE
#  Found libarchive 3.6.0 zlib/1.2.11 liblzma/5.2.5 bz2lib/1.0.8 liblz4/1.9.3 libzstd/1.4.8
# Page segmentation modes:
#   0    Orientation and script detection (OSD) only.
#   1    Automatic page segmentation with OSD.
#   2    Automatic page segmentation, but no OSD, or OCR. (not implemented)
#   3    Fully automatic page segmentation, but no OSD. (Default)
#   4    Assume a single column of text of variable sizes.
#   5    Assume a single uniform block of vertically aligned text.
#   6    Assume a single uniform block of text.
#   7    Treat the image as a single text line.
#   8    Treat the image as a single word.
#   9    Treat the image as a single word in a circle.
#  10    Treat the image as a single character.
#  11    Sparse text. Find as much text as possible in no particular order.
#  12    Sparse text with OSD.
#  13    Raw line. Treat the image as a single text line,
#        bypassing hacks that are Tesseract-specific.

# %%
# !sudo apt-get install -y tesseract-ocr-por
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tesseract-ocr-por
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 856 kB of archives.
# After this operation, 1,998 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-por all 1:4.00~git30-7274cfa-1.1 [856 kB]
# Fetched 856 kB in 1s (1,084 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package tesseract-ocr-por.
# (Reading database ... 126111 files and directories currently installed.)
# Preparing to unpack .../tesseract-ocr-por_1%3a4.00~git30-7274cfa-1.1_all.deb ...
# Unpacking tesseract-ocr-por (1:4.00~git30-7274cfa-1.1) ...
# Setting up tesseract-ocr-por (1:4.00~git30-7274cfa-1.1) ...

# %%
# !tesseract --list-langs
# Out:
# List of available languages (3):
# eng
# osd
# por

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Create hypothesis

# %%
import os
import cv2
import pytesseract
import matplotlib.pyplot as plt

# Base folder where the subfolders with images are located
base_folder = '/content/drive/MyDrive/crops_Yolo_back'

# File path with the list of folders to be processed
image_list_file = '/content/drive/MyDrive/dataset_back/test_files.txt'


config = r'--oem 3 --psm 7'

# Function to perform text recognition in an image
def perform_ocr(image_path):
    img = cv2.imread(image_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(img, lang="por", config=config)
    text = text.replace("\n", "").replace("\x0c", "").replace("\u2014", "")
    return text, img

with open(image_list_file, 'r') as f:
    folders_to_process = f.read().strip().split(',')
    folders_to_process = [arquivo.strip() for arquivo in folders_to_process]

for folder_name in os.listdir(base_folder):
    if folder_name in folders_to_process:
        folder_path = os.path.join(base_folder, folder_name)
        if os.path.isdir(folder_path):
            output_file = f'/content/drive/MyDrive/Tesseract/resultados_yolo_back/{folder_name}/hipotese.txt'
            output_folder = os.path.dirname(output_file)

            if not os.path.exists(output_folder):
                os.makedirs(output_folder)

            ocr_results = []

            for filename in os.listdir(folder_path):
                if filename.endswith(('.png', '.jpg', '.jpeg')):
                    image_path = os.path.join(folder_path, filename)
                    ocr_text, image = perform_ocr(image_path)
                    ocr_results.append((filename.split('.')[0], ocr_text))

            with open(output_file, 'w') as txt_file:
                for image_id, ocr_text in ocr_results:
                    txt_file.write(f'{image_id} "{ocr_text}"\n')

            print(f'All results were saved in {output_file}')
# Out:
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007256/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007257/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007258/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007259/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007260/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007261/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007262/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007263/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007264/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007265/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007266/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007267/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007268/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007269/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007270/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007271/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007272/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007273/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007274/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007275/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007276/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007277/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007278/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007279/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007280/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007281/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007282/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007283/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007284/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007285/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007286/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007287/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007288/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007289/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007290/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007291/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007292/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007293/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007294/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007295/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007296/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007297/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007298/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007299/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007300/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007301/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007302/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007303/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007304/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007305/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007306/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007307/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007308/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007309/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007310/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007311/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007312/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007313/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007314/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007315/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007316/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007317/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007318/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007319/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007320/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007321/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007322/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007323/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007324/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007325/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007326/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007327/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007328/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007329/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007330/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007331/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007332/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007333/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007334/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007335/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007336/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007337/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007338/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007339/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007340/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007341/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007342/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007343/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007344/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007345/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007346/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007347/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007348/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007349/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007350/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007351/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007352/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007353/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007354/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007355/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007356/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007357/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007358/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007359/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007360/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007361/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007362/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007363/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007364/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007365/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007366/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007367/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007368/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007369/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007370/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007371/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007372/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007373/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007374/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007375/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007376/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007377/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007378/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007379/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007380/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007381/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007382/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007383/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007384/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007385/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007386/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007387/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007388/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007389/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007390/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007391/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007392/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007393/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007394/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007395/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007396/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007397/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007398/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007399/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007400/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007401/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007402/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007403/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007404/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007405/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007406/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007407/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007408/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007409/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007410/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007411/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007412/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007413/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007414/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007415/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007416/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007417/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007418/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007419/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007420/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007421/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007422/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007423/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007424/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007425/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007426/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007427/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007428/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007429/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007430/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007431/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007432/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007433/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007434/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007435/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007436/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007437/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007438/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007439/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007440/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007441/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007442/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007443/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007444/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007445/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007446/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007447/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007448/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007449/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007450/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007451/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007452/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007453/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007454/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007455/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007456/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007457/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007458/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007459/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007460/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007461/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007462/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007463/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007464/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007465/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007466/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007467/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007468/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007469/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007470/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007471/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007472/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007473/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007474/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007475/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007476/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007477/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007478/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007479/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007480/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007481/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007482/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007483/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007484/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007485/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007486/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007487/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007488/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007489/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007490/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007491/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007492/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007493/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007494/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007495/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007496/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007497/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007498/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007499/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007500/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007501/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007502/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007503/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007504/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007505/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007506/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007507/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007508/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007509/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007510/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007511/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007512/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007513/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007514/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007515/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007516/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007517/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007518/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007519/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007520/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007521/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007522/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007523/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007524/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007525/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007526/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007527/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007528/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007529/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007530/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007531/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007532/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007533/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007534/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007535/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007536/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007537/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007538/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007539/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007540/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007541/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007542/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007543/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007544/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007545/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007546/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007547/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007548/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007549/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007550/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007551/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007552/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007553/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007554/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007555/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007556/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007557/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007558/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007559/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007560/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007561/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007562/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007563/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007564/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007565/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007566/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007567/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007568/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007569/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007570/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007571/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007572/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007573/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007574/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007575/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007576/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007577/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007578/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007579/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007580/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007581/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007582/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007583/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007584/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007585/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007586/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007587/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007588/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007589/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007590/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007591/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007592/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007593/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007594/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007595/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007596/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007597/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007598/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007599/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007600/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007601/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007602/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007603/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007604/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007605/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007606/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007607/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007608/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007609/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007610/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007611/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007612/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007613/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007614/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007615/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007616/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007617/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007618/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007619/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007620/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007621/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007622/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007623/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007624/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007625/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007626/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007627/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007628/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007629/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007630/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007631/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007632/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007633/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007634/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007635/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007636/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007637/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007638/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007639/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007640/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007641/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007642/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007643/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007644/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007645/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007646/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007647/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007648/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007649/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007650/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007651/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007652/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007653/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007654/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007655/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007656/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007657/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007658/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007659/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007660/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007661/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007662/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007663/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007664/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007665/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007666/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007667/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007668/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007669/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007670/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007671/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007672/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007673/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007674/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007675/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007676/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007677/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007678/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007679/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007680/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007681/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007682/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007683/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007684/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007685/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007686/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007687/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007688/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007689/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007690/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007691/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007692/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007693/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007694/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007695/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007696/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007697/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007698/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007699/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007700/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007701/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007702/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007703/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007704/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007705/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007706/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007707/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007708/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007709/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007710/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007711/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007712/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007713/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007714/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007715/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007716/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007717/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007718/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007719/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007720/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007721/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007722/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007723/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007724/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007725/hipotese.txt
# ...
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007820/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007821/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007822/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007823/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007824/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007825/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007826/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007827/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007828/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007829/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007830/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007831/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007832/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007833/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007834/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007835/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007836/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007837/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007838/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007839/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007840/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007841/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007842/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007843/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007844/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007845/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007846/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007847/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007848/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007849/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007850/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007851/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007852/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007853/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007854/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007855/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007856/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007857/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007858/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007859/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007860/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007861/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007862/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007863/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007864/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007865/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007866/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007867/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007868/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007869/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007870/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007871/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007872/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007873/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007874/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007875/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007876/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007877/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007878/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007879/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007880/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007881/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007882/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007883/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007884/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007885/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007886/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007887/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007888/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007889/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007890/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007891/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007892/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007893/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007894/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007895/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007896/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007897/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007898/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007899/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007900/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007901/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007902/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007903/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007904/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007905/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007906/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007907/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007908/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007909/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007910/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007911/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007912/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007913/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007914/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007915/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007916/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007917/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007918/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007919/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007920/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007921/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007922/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007923/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007924/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007925/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007926/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007927/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007928/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007929/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007930/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007931/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007932/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007933/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007934/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007935/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007936/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007937/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007938/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007939/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007940/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007941/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007942/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007943/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007944/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007945/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007946/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007947/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007948/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007949/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007950/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007951/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007952/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007953/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007954/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007955/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007956/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007957/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007958/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007959/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007960/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007961/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007962/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007963/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007964/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007965/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007966/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007967/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007968/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007969/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007970/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007971/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007972/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007973/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007974/hipotese.txt
# All results were saved in /content/drive/MyDrive/Tesseract/resultados_yolo_back/00007975/hipotese.txt

# %%
import os

folder_path = '/content/drive/MyDrive/Tesseract/resultados_yolo_back'
folders = [f for f in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, f))]

print(f"Total de pastas: {len(folders)}")
# Out:
# Total de pastas: 720
