# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Standardize result

# %%
import json
import re
import os

def map_json_to_format(data):
    mapping = {
      # 01 - Número
      "numero": 0,
      "número": 0,

      # 1 - Código
      "codigo": 1,
      "código": 1,

      # 2 - Número Lateral
      "numero lateral": 2,
      "numero_lateral": 2,
      "número lateral": 2,
      "número_lateral": 2,

      # 3 - Local
      "local": 3,

      # 4 - Data Emissão
      "data_emissao": 4,
      "data emissao": 4,
      "data_emissão": 4,
      "data emissão": 4,
      "dataemissao": 4,
      "dataemissão": 4,


      # 5 - Assinatura Emissor
      "assinar_emissor": 5,
      "assinatura emissor": 5,
      "assinatura_emissor": 5,
      "assinatura_emitente": 5,
      "assinado_em": 5,


      # 6 - Observações
      "observacoes": 6,
      "observações": 6,
    }

    result_dict = {}

    for key, value in mapping.items():
        if key in data and data[key]:
            if isinstance(data[key], list):
                if all(isinstance(item, dict) for item in data[key]):
                    data[key] = ' '.join(
                        re.sub(r'\\', '', value) for obj in data[key] for value in obj.values()
                    )
                else:
                    data[key] = ' '.join(
                        item.replace('\\', '') for item in data[key]
                    )
            elif isinstance(data[key], dict):
                data[key] = ' '.join(
                    re.sub(r'\\', '', value) for value in data[key].values()
                )
            else:
                data[key] = data[key].replace('\\', '')
            print(data[key])
            if value in result_dict:
                result_dict[value] += f" {data[key]}"
            else:
                result_dict[value] = f'{data[key]}'

    result = [f'{key} "{value}"' for key, value in result_dict.items()]
    print(result)
    return result


def extract_json_from_txt(txt_content):
    json_match = re.search(r'\{.*\}', txt_content, re.DOTALL)

    if json_match:
        cleaned_json_str = json_match.group().replace('\\', '\\\\')
        return json.loads(cleaned_json_str)
    else:
        print("No JSON blocks found in file")

def process_and_save_txt_file(input_file_path, output_file_path):
    with open(input_file_path, 'r', encoding='utf-8') as file:
        txt_content = file.read()

    data = extract_json_from_txt(txt_content)

    if (data):
      formatted_data = map_json_to_format(data)

      output_dir = os.path.dirname(output_file_path)
      if not os.path.exists(output_dir):
          os.makedirs(output_dir)

      with open(output_file_path, 'w', encoding='utf-8') as file:
          for line in formatted_data:
              file.write(line + '\n')

# Path to input (gpt return) and output (formatted return) folders
input_base_dir = '/content/drive/MyDrive/GPT/resultados_gpt_mini_back'
output_base_dir = '/content/drive/MyDrive/GPT/resultados_gpt_mini_back_formatado'

# Traverse all subfolders of the input directory
for folder_name in os.listdir(input_base_dir):
    input_folder_path = os.path.join(input_base_dir, folder_name)

    if os.path.isdir(input_folder_path):
        input_file_path = os.path.join(input_folder_path, 'hipotese.txt')

        if os.path.exists(input_file_path):
            output_folder_path = os.path.join(output_base_dir, folder_name)
            output_file_path = os.path.join(output_folder_path, 'resultado.txt')

            print(input_file_path)
            process_and_save_txt_file(input_file_path, output_file_path)

        else:
            print(f"File 'hipotese.txt' not found in: {input_folder_path}")
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# DAQUINO CAWAM
# Y; J;
# ['0 "88171989117"', '1 "PB998087750"', '2 "212915602"', '3 "ROTEIRO-AL"', '4 "11/08/1983"', '5 "DAQUINO CAWAM"', '6 "Y; J;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007334/hipotese.txt
# 088713455
# PA107330939
# 43621648098
# MONTE BÉLO-MG
# 12/08/2002
# ANTONAGI KEI
# ['0 "088713455"', '1 "PA107330939"', '2 "43621648098"', '3 "MONTE BÉLO-MG"', '4 "12/08/2002"', '5 "ANTONAGI KEI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007335/hipotese.txt
# 30073745432
# BA125670990
# 958410557
# CHOROZINHO-CE
# 19/03/1989
# DETRAN MG (MINAS GERAIS)
# IN CORDOUTIS FRE
# ['0 "30073745432"', '1 "BA125670990"', '2 "958410557"', '3 "CHOROZINHO-CE"', '4 "19/03/1989"', '5 "DETRAN MG (MINAS GERAIS)"', '6 "IN CORDOUTIS FRE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007336/hipotese.txt
# 36866510086
# SP745305186
# 4211813
# VANINI-RS
# 08/10/1990
# GREVE PINATTI AKU
# ['0 "36866510086"', '1 "SP745305186"', '2 "4211813"', '3 "VANINI-RS"', '4 "08/10/1990"', '5 "GREVE PINATTI AKU"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007337/hipotese.txt
# 03706783505
# SC917221162
# 389767900
# MATINHAS-PB
# 04/10/1987
# MARCELLO URVANE COSTA
# ['0 "03706783505"', '1 "SC917221162"', '2 "389767900"', '3 "MATINHAS-PB"', '4 "04/10/1987"', '5 "MARCELLO URVANE COSTA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007338/hipotese.txt
# 470393852
# PEROLÂNDIA-GO
# 02/04/1951
# CHIMENTI EUGENIO S
# ['1 "470393852"', '3 "PEROLÂNDIA-GO"', '4 "02/04/1951"', '5 "CHIMENTI EUGENIO S"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007339/hipotese.txt
# 938305869
# ARACAJI-PB
# 02/02/1955
# HELMARKECH ALGE B
# ['1 "938305869"', '3 "ARACAJI-PB"', '4 "02/02/1955"', '5 "HELMARKECH ALGE B"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007340/hipotese.txt
# 27904794416
# PA988049307
# 102040158
# BELEM-AL
# 02/10/1967
# LORENA MAIKON
# ['0 "27904794416"', '1 "PA988049307"', '2 "102040158"', '3 "BELEM-AL"', '4 "02/10/1967"', '5 "LORENA MAIKON"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007341/hipotese.txt
# 461866046
# BA817315981
# T:
# RECIFE-PE
# 10/04/1980
# KUNIYOSHI CABIAN
# ['0 "461866046"', '1 "BA817315981"', '2 "T:"', '3 "RECIFE-PE"', '4 "10/04/1980"', '5 "KUNIYOSHI CABIAN"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007342/hipotese.txt
# 13559224040
# 516083013
# SERRANA-SP
# 26/02/1954
# NAOTTO SHEYAN
# ['0 "13559224040"', '1 "516083013"', '3 "SERRANA-SP"', '4 "26/02/1954"', '5 "NAOTTO SHEYAN"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007343/hipotese.txt
# 47724910814
# 834164587
# SANTA MARIA DO SUACUI-MG
# 17/12/1961
# DETRAN DF (DISTRITO FEDERAL)
# ['0 "47724910814"', '1 "834164587"', '3 "SANTA MARIA DO SUACUI-MG"', '4 "17/12/1961"', '5 "DETRAN DF (DISTRITO FEDERAL)"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007344/hipotese.txt
# 048295877
# ITAÚ-RN
# 13/03/1988
# APOLLO GRIGÓLIO SO
# ['1 "048295877"', '3 "ITAÚ-RN"', '4 "13/03/1988"', '5 "APOLLO GRIGÓLIO SO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007345/hipotese.txt
# 480455943539
# RS420512585
# 169542723
# MORRINHOS-CE
# 18/10/1985
# MONTES TERUKAZU VITH
# ['0 "480455943539"', '1 "RS420512585"', '2 "169542723"', '3 "MORRINHOS-CE"', '4 "18/10/1985"', '5 "MONTES TERUKAZU VITH"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007346/hipotese.txt
# 192208449
# CURITIVA-PR
# 13/01/1987
# Fukai Domini
# ['0 "192208449"', '3 "CURITIVA-PR"', '4 "13/01/1987"', '5 "Fukai Domini"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007347/hipotese.txt
# 088713455
# PA107330939
# 43621648098
# MONTE BELO-MG
# 12/08/2022
# ANTONAGI KEI
# ['0 "088713455"', '1 "PA107330939"', '2 "43621648098"', '3 "MONTE BELO-MG"', '4 "12/08/2022"', '5 "ANTONAGI KEI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007348/hipotese.txt
# 341539449
# ES976450438
# 57735442255
# RIO NOVO-MG
# 08/09/1966
# FEEDRICE TOMA
# ['0 "341539449"', '1 "ES976450438"', '2 "57735442255"', '3 "RIO NOVO-MG"', '4 "08/09/1966"', '5 "FEEDRICE TOMA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007349/hipotese.txt
# 042161790
# ACARI-RN
# 29/05/1957
# IAK HERANE MA
# ['1 "042161790"', '3 "ACARI-RN"', '4 "29/05/1957"', '5 "IAK HERANE MA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007350/hipotese.txt
# 83708545308
# MG345590331
# 390725567
# DOBRADA-SP
# 05/03/1970
# DET PR (PARANÁ)
# ['0 "83708545308"', '1 "MG345590331"', '2 "390725567"', '3 "DOBRADA-SP"', '4 "05/03/1970"', '5 "DET PR (PARANÁ)"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007351/hipotese.txt
# 968239
# 30319520837
# CRAVATA DE
# 29/08/2023
# ['0 "968239"', '1 "30319520837"', '3 "CRAVATA DE"', '4 "29/08/2023"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007352/hipotese.txt
# 327609822
# IBICUI-BA
# 15/12/1956
# YONEKURA FARNES C
# I;
# ['1 "327609822"', '3 "IBICUI-BA"', '4 "15/12/1956"', '5 "YONEKURA FARNES C"', '6 "I;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007353/hipotese.txt
# 024092150
# ITACUAÍ RJ
# 23/04/1984
# ALEKSANDRO KOZATA
# ['1 "024092150"', '3 "ITACUAÍ RJ"', '4 "23/04/1984"', '5 "ALEKSANDRO KOZATA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007354/hipotese.txt
# 34367546191
# MG941230267
# 605819431
# MIRANDA-MS
# 18/11/2000
# ['0 "34367546191"', '1 "MG941230267"', '2 "605819431"', '3 "MIRANDA-MS"', '4 "18/11/2000"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007355/hipotese.txt
# 43327055957
# 180421514
# CAPINZAL-SC
# 15/12/1952
# CANDELEIRO TOZET CALDEIRA
# ['0 "43327055957"', '1 "180421514"', '3 "CAPINZAL-SC"', '4 "15/12/1952"', '5 "CANDELEIRO TOZET CALDEIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007356/hipotese.txt
# 000006887372
# 144531822
# PONTO LUCENA-DS
# 05/09/1959
# ['0 "000006887372"', '1 "144531822"', '3 "PONTO LUCENA-DS"', '4 "05/09/1959"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007357/hipotese.txt
# 32043937932
# RO338154991
# 21541187
# SILVEIRÂNIA-MG
# 29/11/1998
# TORBITONI MASSADI REZ
# ['0 "32043937932"', '1 "RO338154991"', '2 "21541187"', '3 "SILVEIRÂNIA-MG"', '4 "29/11/1998"', '5 "TORBITONI MASSADI REZ"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007358/hipotese.txt
# 013167049
# CAMPOS VERDES-GO
# 06/03/1989
# FORIGO MASSUO
# ['0 "013167049"', '3 "CAMPOS VERDES-GO"', '4 "06/03/1989"', '5 "FORIGO MASSUO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007359/hipotese.txt
# 732309217
# SP029043648
# 732009217
# CORBÉLIA-PR
# 04/09/1975
# BUGANO BOURROU
# ['0 "732309217"', '1 "SP029043648"', '2 "732009217"', '3 "CORBÉLIA-PR"', '4 "04/09/1975"', '5 "BUGANO BOURROU"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007360/hipotese.txt
# 862540139
# T0078193816
# 13232761680
# CONCHAS-SP
# 22/03/2017
# PESCAROLI SALLES
# O; H; C; E;
# ['0 "862540139"', '1 "T0078193816"', '2 "13232761680"', '3 "CONCHAS-SP"', '4 "22/03/2017"', '5 "PESCAROLI SALLES"', '6 "O; H; C; E;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007361/hipotese.txt
# 30
# 19434867078
# 390893729
# MODOCA-MA
# 30/03/2009
# KENN YUGO UZZI
# ['0 "30"', '1 "19434867078"', '2 "390893729"', '3 "MODOCA-MA"', '4 "30/03/2009"', '5 "KENN YUGO UZZI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007362/hipotese.txt
# 24359847107
# BA069437600
# 686413447
# CAPIM-PB
# 17/01/1967
# I;
# ['0 "24359847107"', '1 "BA069437600"', '2 "686413447"', '3 "CAPIM-PB"', '4 "17/01/1967"', '6 "I;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007363/hipotese.txt
# 99973346157
# 681909576
# GUARÂNIA - SP
# 20/12/1968
# TRAVASSOS CONCEL
# ['0 "99973346157"', '1 "681909576"', '3 "GUARÂNIA - SP"', '4 "20/12/1968"', '5 "TRAVASSOS CONCEL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007364/hipotese.txt
# 129991735
# 49680595393
# VARZEA-PB
# 12/05/1989
# NARAZORA ROLF MUBL
# ['1 "129991735"', '2 "49680595393"', '3 "VARZEA-PB"', '4 "12/05/1989"', '5 "NARAZORA ROLF MUBL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007365/hipotese.txt
# 30658767495
# PR165647227
# 622930834
# SARDOÁ-MG
# 30/08/1977
# MOSER CANSANCAO
# ['0 "30658767495"', '1 "PR165647227"', '2 "622930834"', '3 "SARDOÁ-MG"', '4 "30/08/1977"', '5 "MOSER CANSANCAO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007366/hipotese.txt
# 326667089
# MG447244673
# 326667089
# SANTO ANTÔNIO-RN
# 22/10/1952
# JOJIMA TANKITI P
# ['0 "326667089"', '1 "MG447244673"', '2 "326667089"', '3 "SANTO ANTÔNIO-RN"', '4 "22/10/1952"', '5 "JOJIMA TANKITI P"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007367/hipotese.txt
# 92450976705
# PR863193423
# 135065820
# SÃO MANOEL DO PARANÁ-PR
# 27/10/1962
# GRÄJEW LÇQUER
# ['0 "92450976705"', '1 "PR863193423"', '2 "135065820"', '3 "SÃO MANOEL DO PARANÁ-PR"', '4 "27/10/1962"', '5 "GRÄJEW LÇQUER"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007368/hipotese.txt
# 987906390580
# 269073593
# EXU-PE
# EXU-PE
# 06/06/1950
# MASUCHELI OD
# ['0 "987906390580"', '1 "269073593"', '2 "EXU-PE"', '3 "EXU-PE"', '4 "06/06/1950"', '5 "MASUCHELI OD"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007369/hipotese.txt
# 47282427951
# A1439948475
# 532671731
# NOVO HORIZONTE-SP
# 22/03/1959
# CAPPELLARI SEDITYAM
# ['0 "47282427951"', '1 "A1439948475"', '2 "532671731"', '3 "NOVO HORIZONTE-SP"', '4 "22/03/1959"', '5 "CAPPELLARI SEDITYAM"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007370/hipotese.txt
# 8898715042
# 0524941387
# 9313546250
# PACUARANA PR
# 02/10/2008
# ASSINATURA DO EMISSOR
# ['0 "8898715042"', '1 "0524941387"', '2 "9313546250"', '3 "PACUARANA PR"', '4 "02/10/2008"', '5 "ASSINATURA DO EMISSOR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007371/hipotese.txt
# 61163092922
# AL512998969
# 409919037
# Aquidauana-MS
# 17/01/1973
# SPURI VELLEGO G
# ['0 "61163092922"', '1 "AL512998969"', '2 "409919037"', '3 "Aquidauana-MS"', '4 "17/01/1973"', '5 "SPURI VELLEGO G"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007372/hipotese.txt
# 72294046512
# 32253317
# CUJABA-MT
# 21/04/2018
# SAGLIETTI S
# ['0 "72294046512"', '1 "32253317"', '3 "CUJABA-MT"', '4 "21/04/2018"', '5 "SAGLIETTI S"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007373/hipotese.txt
# 21676955643
# PRO51118062
# 845969578
# ROSÁRIO DO IVAÍ-PR
# 13/06/1968
# PROSPERO LLO
# ['0 "21676955643"', '1 "PRO51118062"', '2 "845969578"', '3 "ROSÁRIO DO IVAÍ-PR"', '4 "13/06/1968"', '5 "PROSPERO LLO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007374/hipotese.txt
# 381561325
# 0066177741Q
# T;
# JEREMOABO-BA
# 03/10/1958
# LICIANE RUDA GAT
# ['0 "381561325"', '1 "0066177741Q"', '2 "T;"', '3 "JEREMOABO-BA"', '4 "03/10/1958"', '5 "LICIANE RUDA GAT"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007375/hipotese.txt
# 752678692
# SP747847286
# 93560167083
# JAPI-RN
# 28/10/1994
# KAROL MILONE
# ['0 "752678692"', '1 "SP747847286"', '2 "93560167083"', '3 "JAPI-RN"', '4 "28/10/1994"', '5 "KAROL MILONE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007376/hipotese.txt
# 219651190
# G0840877999
# DUMONT-SP
# 21/02/2012
# KOSTRISCH THOMAIZE
# V;
# ['0 "219651190"', '1 "G0840877999"', '3 "DUMONT-SP"', '4 "21/02/2012"', '5 "KOSTRISCH THOMAIZE"', '6 "V;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007377/hipotese.txt
# 97826723134
# MG756406153
# 654993757
# CUPARAQUE-MG
# 10/10/2012
# LOPES PASSALACQ
# ['0 "97826723134"', '1 "MG756406153"', '2 "654993757"', '3 "CUPARAQUE-MG"', '4 "10/10/2012"', '5 "LOPES PASSALACQ"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007378/hipotese.txt
# 763640592869
# SC441488329
# 606268858
# MALTA-PB
# 28/01/1985
# ROSETTI MITSUGUI ARAGAO
# B; G;
# ['0 "763640592869"', '1 "SC441488329"', '2 "606268858"', '3 "MALTA-PB"', '4 "28/01/1985"', '5 "ROSETTI MITSUGUI ARAGAO"', '6 "B; G;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007379/hipotese.txt
# 018103560
# MG174397952
# 56319319789
# BARRA D' ALCÂNTARA-PI
# 28/03/2004
# FRASATTO GERMANO
# ['0 "018103560"', '1 "MG174397952"', '2 "56319319789"', '3 "BARRA D\' ALCÂNTARA-PI"', '4 "28/03/2004"', '5 "FRASATTO GERMANO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007380/hipotese.txt
# 097711916
# 62637951117
# SÃO JOSÉ DO BONFIM-PB
# 16/09/1998
# MELLA IWAMI TIYOMI
# CE066055396
# ['1 "097711916"', '2 "62637951117"', '3 "SÃO JOSÉ DO BONFIM-PB"', '4 "16/09/1998"', '5 "MELLA IWAMI TIYOMI"', '6 "CE066055396"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007381/hipotese.txt
# 94367546191
# MG941830627
# 605810811
# MIRANDA-MS
# 18/11/2000
# FINCATO SAMANTA BOL
# ['0 "94367546191"', '1 "MG941830627"', '2 "605810811"', '3 "MIRANDA-MS"', '4 "18/11/2000"', '5 "FINCATO SAMANTA BOL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007382/hipotese.txt
# 527850309
# PB031757414
# 527850309
# INDIANA-SP
# 16/04/1991
# YIDUKA ZOI SEJE FERNANDES
# E;
# ['0 "527850309"', '1 "PB031757414"', '2 "527850309"', '3 "INDIANA-SP"', '4 "16/04/1991"', '5 "YIDUKA ZOI SEJE FERNANDES"', '6 "E;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007383/hipotese.txt
# 56114572057
# R623317578
# 325110183
# ARUJÁ-SP
# 05/05/1988
# MATTIO NAKID
# ['0 "56114572057"', '1 "R623317578"', '2 "325110183"', '3 "ARUJÁ-SP"', '4 "05/05/1988"', '5 "MATTIO NAKID"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007384/hipotese.txt
# 64631936939
# MT769544700
# 513497621
# SÃO FELIPE-BA
# 24/04/1961
# BERAN SEFRIN ACH MARTINS
# ['0 "64631936939"', '1 "MT769544700"', '2 "513497621"', '3 "SÃO FELIPE-BA"', '4 "24/04/1961"', '5 "BERAN SEFRIN ACH MARTINS"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007385/hipotese.txt
# 21520881252
# MG802184608
# 9494836563
# CRISTALÂNDIA DO PIAUÍ-PI
# 14/05/1999
# ['0 "21520881252"', '1 "MG802184608"', '2 "9494836563"', '3 "CRISTALÂNDIA DO PIAUÍ-PI"', '4 "14/05/1999"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007386/hipotese.txt
# 92756264731
# G0145227849
# 191725867
# QUIJINGUE-BA
# 01/01/2001
# CAVALCANTI
# EXERCE ATIVIDADE REMUNERADA;
# ['0 "92756264731"', '1 "G0145227849"', '2 "191725867"', '3 "QUIJINGUE-BA"', '4 "01/01/2001"', '5 "CAVALCANTI"', '6 "EXERCE ATIVIDADE REMUNERADA;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007387/hipotese.txt
# 130822401
# AP280340577
# PINHEIRO PRETO-SC
# 08/10/2001
# RUANIE BONANNO KISAX 42250712482
# ['0 "130822401"', '1 "AP280340577"', '3 "PINHEIRO PRETO-SC"', '4 "08/10/2001"', '5 "RUANIE BONANNO KISAX 42250712482"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007388/hipotese.txt
# 74836085436
# 601146601
# 601146601
# PEDRÃO-BA
# 28/12/2009
# CAVAZZANA RÊNAM
# ['0 "74836085436"', '1 "601146601"', '2 "601146601"', '3 "PEDRÃO-BA"', '4 "28/12/2009"', '5 "CAVAZZANA RÊNAM"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007389/hipotese.txt
# 40375184
# R340943043
# 65909739511
# CALUMBI-PE
# 21/11/1990
# CHEVALIER TOM
# ['0 "40375184"', '1 "R340943043"', '2 "65909739511"', '3 "CALUMBI-PE"', '4 "21/11/1990"', '5 "CHEVALIER TOM"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007390/hipotese.txt
# 34610221406
# 09053258
# LAGOA DO CEDRO - RS
# 22/04/1994
# LAIZA BURKHARDT
# ['0 "34610221406"', '1 "09053258"', '3 "LAGOA DO CEDRO - RS"', '4 "22/04/1994"', '5 "LAIZA BURKHARDT"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007391/hipotese.txt
# 180421514
# CAPINZAL-SC
# 15/12/1952
# CANDLEIRO TOZET CALDEIRA
# ['1 "180421514"', '3 "CAPINZAL-SC"', '4 "15/12/1952"', '5 "CANDLEIRO TOZET CALDEIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007392/hipotese.txt
# 81400960249
# ES173699314
# 96566932
# CALMON-SC
# 31/03/1963
# BARAGLIA KABAS
# ['0 "81400960249"', '1 "ES173699314"', '2 "96566932"', '3 "CALMON-SC"', '4 "31/03/1963"', '5 "BARAGLIA KABAS"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007393/hipotese.txt
# 201879724
# PB082298107
# 8151245102
# GOIANINHA-RN
# 19/01/1958
# DETRAN RJ RIO DE JANEIRO
# ['0 "201879724"', '1 "PB082298107"', '2 "8151245102"', '3 "GOIANINHA-RN"', '4 "19/01/1958"', '5 "DETRAN RJ RIO DE JANEIRO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007394/hipotese.txt
# 81149527145
# PK684646332
# 741304451
# CAEM-BA
# 02/02/1990
# BOZZANE EDNEI VI CALDEIRA
# ['0 "81149527145"', '1 "PK684646332"', '2 "741304451"', '3 "CAEM-BA"', '4 "02/02/1990"', '5 "BOZZANE EDNEI VI CALDEIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007395/hipotese.txt
# 190469596
# FR7539262511
# 190469596
# TAPIRA-PR
# 21/01/2014
# HUYRA MUDERTO AGN
# U;
# ['0 "190469596"', '1 "FR7539262511"', '2 "190469596"', '3 "TAPIRA-PR"', '4 "21/01/2014"', '5 "HUYRA MUDERTO AGN"', '6 "U;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007396/hipotese.txt
# 935834721
# GUARINOS-GO
# 26/08/2002
# VENTUROLI QEST NUNES
# EXERCE ATIVIDADE REMUNERADA;
# ['1 "935834721"', '3 "GUARINOS-GO"', '4 "26/08/2002"', '5 "VENTUROLI QEST NUNES"', '6 "EXERCE ATIVIDADE REMUNERADA;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007397/hipotese.txt
# 22141430343
# MG792393734
# 61060627
# NOBRES-MT
# 19/12/1990
# WEST PERRACINI M
# ['0 "22141430343"', '1 "MG792393734"', '2 "61060627"', '3 "NOBRES-MT"', '4 "19/12/1990"', '5 "WEST PERRACINI M"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007398/hipotese.txt
# 98059461144
# RN640530446
# 772702688
# LUCRÉCIA-RN
# 22/12/1970
# NOVÍS EDILAIN
# ['0 "98059461144"', '1 "RN640530446"', '2 "772702688"', '3 "LUCRÉCIA-RN"', '4 "22/12/1970"', '5 "NOVÍS EDILAIN"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007399/hipotese.txt
# 21520881252
# MG802184608
# 9494835653
# CRISTALÂNDIA DO PIAUÍ-PI
# 14/05/1999
# ['0 "21520881252"', '1 "MG802184608"', '2 "9494835653"', '3 "CRISTALÂNDIA DO PIAUÍ-PI"', '4 "14/05/1999"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007400/hipotese.txt
# 98779630860
# 269073593
# 269073593
# EXU-PE
# 06/06/1950
# MASUCHELLI OD
# EXERCE ATIVIDADE REMUNERADA; A; EXERCE ATIVIDADE REMUNERADA;
# ['0 "98779630860"', '1 "269073593"', '2 "269073593"', '3 "EXU-PE"', '4 "06/06/1950"', '5 "MASUCHELLI OD"', '6 "EXERCE ATIVIDADE REMUNERADA; A; EXERCE ATIVIDADE REMUNERADA;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007401/hipotese.txt
# 20531910036
# MA471485919
# 052249800
# TOCANTÍNIA-TO
# 06/09/2009
# V;
# ['0 "20531910036"', '1 "MA471485919"', '2 "052249800"', '3 "TOCANTÍNIA-TO"', '4 "06/09/2009"', '6 "V;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007402/hipotese.txt
# 830643302496
# 7183881
# ALTO LONGA-PI
# 16/02/1960
# PALOPOLI PEGORER
# ['0 "830643302496"', '1 "7183881"', '3 "ALTO LONGA-PI"', '4 "16/02/1960"', '5 "PALOPOLI PEGORER"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007403/hipotese.txt
# 013167049
# BA860152636
# 47406129450
# CAMPOS VERDES-GO
# 06/03/1989
# FORIGO MASSOU
# ['0 "013167049"', '1 "BA860152636"', '2 "47406129450"', '3 "CAMPOS VERDES-GO"', '4 "06/03/1989"', '5 "FORIGO MASSOU"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007404/hipotese.txt
# 527977723365
# SE924937092
# 223922765
# RODELAS-BA
# ASSIS-SP
# GUMERCINDO BAILO ARA
# EXERCE ATIVIDADE REMUNERADA; E; V;
# ['0 "527977723365"', '1 "SE924937092"', '2 "223922765"', '3 "RODELAS-BA"', '4 "ASSIS-SP"', '5 "GUMERCINDO BAILO ARA"', '6 "EXERCE ATIVIDADE REMUNERADA; E; V;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007405/hipotese.txt
# 813908050
# SOROCABA-SP
# 15/02/1953
# TYUNG MAISTRAÇOUZ DUARTE
# ['1 "813908050"', '3 "SOROCABA-SP"', '4 "15/02/1953"', '5 "TYUNG MAISTRAÇOUZ DUARTE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007406/hipotese.txt
# 03028450526
# E938715603
# 106621303
# GUAÍRA-SP
# 13/05/1973
# GHERCY KIHARA
# ['0 "03028450526"', '1 "E938715603"', '2 "106621303"', '3 "GUAÍRA-SP"', '4 "13/05/1973"', '5 "GHERCY KIHARA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007407/hipotese.txt
# 796436712
# PB325416397
# 282554863176
# MATO PEA-MT
# 20/04/1966
# SQUAREZ FOWITZKZ BARROS
# I ;
# ['0 "796436712"', '1 "PB325416397"', '2 "282554863176"', '3 "MATO PEA-MT"', '4 "20/04/1966"', '5 "SQUAREZ FOWITZKZ BARROS"', '6 "I ;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007408/hipotese.txt
# 324994964
# BA768942653
# 38287107438
# MURIBECA-SE
# 11/02/1963
# LAUAR ANNI NOEMI ARAUJO
# ['0 "324994964"', '1 "BA768942653"', '2 "38287107438"', '3 "MURIBECA-SE"', '4 "11/02/1963"', '5 "LAUAR ANNI NOEMI ARAUJO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007409/hipotese.txt
# 944887160
# 944887160
# BLUMENAU-SC
# 15/06/2014
# GIESER PANUNT
# ['1 "944887160"', '2 "944887160"', '3 "BLUMENAU-SC"', '4 "15/06/2014"', '5 "GIESER PANUNT"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007410/hipotese.txt
# 238192147606
# P3913827773
# 6168913
# POTENGI-CE
# 26/06/2008
# MANI LEUTWILER AR
# ['0 "238192147606"', '1 "P3913827773"', '2 "6168913"', '3 "POTENGI-CE"', '4 "26/06/2008"', '5 "MANI LEUTWILER AR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007411/hipotese.txt
# 219651190
# G0840877999
# 88835404892
# DUMONT-SP
# 21/02/2012
# KOSTRICH THEMAZEL
# V;
# ['0 "219651190"', '1 "G0840877999"', '2 "88835404892"', '3 "DUMONT-SP"', '4 "21/02/2012"', '5 "KOSTRICH THEMAZEL"', '6 "V;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007412/hipotese.txt
# 404239877
# CHÁ DE ALEGRIA-PE
# 06/06/1966
# NOCE DELIBERTO BENE
# ['1 "404239877"', '3 "CHÁ DE ALEGRIA-PE"', '4 "06/06/1966"', '5 "NOCE DELIBERTO BENE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007413/hipotese.txt
# 006928600
# RJ959394428
# 09780387187
# JÓIA-RS
# 09/05/2008
# CINTO GEHRINGER DA COSTA
# X;
# ['0 "006928600"', '1 "RJ959394428"', '2 "09780387187"', '3 "JÓIA-RS"', '4 "09/05/2008"', '5 "CINTO GEHRINGER DA COSTA"', '6 "X;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007414/hipotese.txt
# 727562700
# RJ944692213
# 49402774680
# JUNDIA-RN
# 10/01/1979
# CALVIELLO KEYI AL
# ['0 "727562700"', '1 "RJ944692213"', '2 "49402774680"', '3 "JUNDIA-RN"', '4 "10/01/1979"', '5 "CALVIELLO KEYI AL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007415/hipotese.txt
# 998253222258
# P414473485
# 112056837
# MONTE SANTO-BA
# 08/02/1975
# THAMARA FUNEMI PREST
# ['0 "998253222258"', '1 "P414473485"', '2 "112056837"', '3 "MONTE SANTO-BA"', '4 "08/02/1975"', '5 "THAMARA FUNEMI PREST"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007416/hipotese.txt
# 569355019
# CE657187509
# 10801597211
# MACATUBA-SP
# 06/04/1974
# ANDRIGO NAINE
# ['0 "569355019"', '1 "CE657187509"', '2 "10801597211"', '3 "MACATUBA-SP"', '4 "06/04/1974"', '5 "ANDRIGO NAINE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007417/hipotese.txt
# 802229824
# BEZERROS-PE
# 24/02/2012
# IAN DULA BORNEA
# Y;
# ['1 "802229824"', '3 "BEZERROS-PE"', '4 "24/02/2012"', '5 "IAN DULA BORNEA"', '6 "Y;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007418/hipotese.txt
# 121484961
# SABINO-SP
# 17/12/1979
# FAVA BERRO CATAE
# ['1 "121484961"', '3 "SABINO-SP"', '4 "17/12/1979"', '5 "FAVA BERRO CATAE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007419/hipotese.txt
# T9640697
# 265490461
# 34823723740
# ARARENDA-CE
# 29/04/1976
# RICCARDI RI
# ['0 "T9640697"', '1 "265490461"', '2 "34823723740"', '3 "ARARENDA-CE"', '4 "29/04/1976"', '5 "RICCARDI RI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007420/hipotese.txt
# 62840245505
# MT240692461
# 634971529
# MACAMBIRA-SE
# 09/05/2003
# MALHONE MANTELAT ARAGÃO
# S ; J
# ['0 "62840245505"', '1 "MT240692461"', '2 "634971529"', '3 "MACAMBIRA-SE"', '4 "09/05/2003"', '5 "MALHONE MANTELAT ARAGÃO"', '6 "S ; J"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007421/hipotese.txt
# 574881832
# MA404032843
# 88266700693
# GUARACIABA-SC
# 29/07/1963
# JONES TEJIN RASERA
# ['0 "574881832"', '1 "MA404032843"', '2 "88266700693"', '3 "GUARACIABA-SC"', '4 "29/07/1963"', '5 "JONES TEJIN RASERA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007422/hipotese.txt
# 83783080843
# 582776286
# 582776286
# TRINDADE-PE
# 29/12/1955
# MANFREDINE KAMAO
# ['0 "83783080843"', '1 "582776286"', '2 "582776286"', '3 "TRINDADE-PE"', '4 "29/12/1955"', '5 "MANFREDINE KAMAO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007423/hipotese.txt
# 88112494460
# MG024198517
# 454563287
# MALLET-PR
# 03/12/2005
# MASTROBUONO CARAM FERNANDES
# K;
# ['0 "88112494460"', '1 "MG024198517"', '2 "454563287"', '3 "MALLET-PR"', '4 "03/12/2005"', '5 "MASTROBUONO CARAM FERNANDES"', '6 "K;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007424/hipotese.txt
# 91112826949
# P1348721782
# 62371468
# IPITIRA-BA
# 10/06/1993
# FELIPE COUTELO ONE
# ['0 "91112826949"', '1 "P1348721782"', '2 "62371468"', '3 "IPITIRA-BA"', '4 "10/06/1993"', '5 "FELIPE COUTELO ONE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007425/hipotese.txt
# 467123195
# MG676993261
# 65535414255
# TAPEJARA-PR
# 27/01/2013
# IEHUDA DOMENICHE I
# ['0 "467123195"', '1 "MG676993261"', '2 "65535414255"', '3 "TAPEJARA-PR"', '4 "27/01/2013"', '5 "IEHUDA DOMENICHE I"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007426/hipotese.txt
# 611503165
# PR438687802
# 12265382302
# CORBÉLIA-PR
# 19/05/2010
# PRIORS MASSUERO T DA COSTA
# L;
# ['0 "611503165"', '1 "PR438687802"', '2 "12265382302"', '3 "CORBÉLIA-PR"', '4 "19/05/2010"', '5 "PRIORS MASSUERO T DA COSTA"', '6 "L;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007427/hipotese.txt
# 369469459999
# MA554206694
# 66162700
# PARISI-SP
# 20/02/1959
# ESTHER HETSUKO
# ['0 "369469459999"', '1 "MA554206694"', '2 "66162700"', '3 "PARISI-SP"', '4 "20/02/1959"', '5 "ESTHER HETSUKO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007428/hipotese.txt
# 344861505
# 58797083955
# 344861505
# SOBRADO-PB
# 31/07/1977
# STOPATO TAMB
# ['0 "344861505"', '1 "58797083955"', '2 "344861505"', '3 "SOBRADO-PB"', '4 "31/07/1977"', '5 "STOPATO TAMB"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007429/hipotese.txt
# 144563058
# PR473012389
# 12296401494
# CORUMBÁ-MS
# PALMA-MG
# MICAI ORJANA EMÍNCA
# X; P; I;
# ['0 "144563058"', '1 "PR473012389"', '2 "12296401494"', '3 "CORUMBÁ-MS"', '4 "PALMA-MG"', '5 "MICAI ORJANA EMÍNCA"', '6 "X; P; I;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007430/hipotese.txt
# 167640510
# GO427460457
# 78904184901
# IBITITARA-BA
# 21/06/1952
# ['0 "167640510"', '1 "GO427460457"', '2 "78904184901"', '3 "IBITITARA-BA"', '4 "21/06/1952"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007431/hipotese.txt
# 10175479389
# ES834007167
# 093809334
# IVAIPORÃ-PR
# 05/02/2007
# NACARATO FO
# ['0 "10175479389"', '1 "ES834007167"', '2 "093809334"', '3 "IVAIPORÃ-PR"', '4 "05/02/2007"', '5 "NACARATO FO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007432/hipotese.txt
# 27072607588
# BA938404532
# 262457043
# JUSCIMEIRA-MT
# 06/09/1956
# VENDRAMIN NAV
# ['0 "27072607588"', '1 "BA938404532"', '2 "262457043"', '3 "JUSCIMEIRA-MT"', '4 "06/09/1956"', '5 "VENDRAMIN NAV"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007433/hipotese.txt
# 321801698
# 14832486089
# PRADO FERREIRAS - PR
# 31/03/1961
# BOCADRO AUTO CHA
# EXERCE ATIVIDADE REMUNERADA;
# ['1 "321801698"', '2 "14832486089"', '3 "PRADO FERREIRAS - PR"', '4 "31/03/1961"', '5 "BOCADRO AUTO CHA"', '6 "EXERCE ATIVIDADE REMUNERADA;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007434/hipotese.txt
# 23613608128
# MGS96745690
# 021478
# NILOPOLIS-RJ
# 29/11/1951
# EUTA BENNETT GUI
# ['0 "23613608128"', '1 "MGS96745690"', '2 "021478"', '3 "NILOPOLIS-RJ"', '4 "29/11/1951"', '5 "EUTA BENNETT GUI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007435/hipotese.txt
# 215205288252
# 949435653
# CRISTALANDIA DO PI ACO P1
# 14/05/1999
# ['0 "215205288252"', '1 "949435653"', '3 "CRISTALANDIA DO PI ACO P1"', '4 "14/05/1999"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007436/hipotese.txt
# 21917194627
# MG442142451
# 514906685
# TUPIRAMA-TO
# 19/12/1990
# LANATOVITZ KOJI
# ['0 "21917194627"', '1 "MG442142451"', '2 "514906685"', '3 "TUPIRAMA-TO"', '4 "19/12/1990"', '5 "LANATOVITZ KOJI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007437/hipotese.txt
# 994898484243
# SCR36451896
# 131403694
# MIGUEL LEÃO-PI
# 04/03/1971
# DETRAN RJ (RIO DE JANEIRO)
# ['0 "994898484243"', '1 "SCR36451896"', '2 "131403694"', '3 "MIGUEL LEÃO-PI"', '4 "04/03/1971"', '5 "DETRAN RJ (RIO DE JANEIRO)"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007438/hipotese.txt
# 05724284968
# CE214059846
# 967293334
# SUMARÉ-SP
# 14/09/1986
# REINATO OSHIYAMA
# ['0 "05724284968"', '1 "CE214059846"', '2 "967293334"', '3 "SUMARÉ-SP"', '4 "14/09/1986"', '5 "REINATO OSHIYAMA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007439/hipotese.txt
# 964145252520
# 181296622
# 181296622
# LINDOESTE-PR
# 12/03/2001
# VARSTREIDLE ST
# ['0 "964145252520"', '1 "181296622"', '2 "181296622"', '3 "LINDOESTE-PR"', '4 "12/03/2001"', '6 "VARSTREIDLE ST"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007440/hipotese.txt
# 382573024
# RJ716171218
# M;
# URUPA-RO
# 01/01/1962
# FERNEDA MOTTI TOVO
# ['0 "382573024"', '1 "RJ716171218"', '2 "M;"', '3 "URUPA-RO"', '4 "01/01/1962"', '5 "FERNEDA MOTTI TOVO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007441/hipotese.txt
# 123456789010
# 0524913587
# BUCARANIA, DR.
# 02/07/2008
# ['0 "123456789010"', '1 "0524913587"', '3 "BUCARANIA, DR."', '4 "02/07/2008"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007442/hipotese.txt
# 953158611
# 62154983173
# 953158611
# DOIS CORREGOS-SP
# 17/03/1953
# DETRAN RJ (RIO DE JANEIRO)
# ['0 "953158611"', '1 "62154983173"', '2 "953158611"', '3 "DOIS CORREGOS-SP"', '4 "17/03/1953"', '5 "DETRAN RJ (RIO DE JANEIRO)"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007443/hipotese.txt
# 27419223667
# GO831629876
# 584721207
# ALAGOAS-MG
# 21/05/1957
# PRADELLA DIAN
# ['0 "27419223667"', '1 "GO831629876"', '2 "584721207"', '3 "ALAGOAS-MG"', '4 "21/05/1957"', '5 "PRADELLA DIAN"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007444/hipotese.txt
# 301505752
# RS185817180
# 88384472553
# RIACHO FRIO-PI
# 06/04/2006
# MAJOLINI MECCHI A
# ['0 "301505752"', '1 "RS185817180"', '2 "88384472553"', '3 "RIACHO FRIO-PI"', '4 "06/04/2006"', '5 "MAJOLINI MECCHI A"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007445/hipotese.txt
# 30188720431
# BA295610409
# 575480002
# BANANAL-SP
# 02/03/1959
# ABUKAMA SOLIS ROZ
# E;
# ['0 "30188720431"', '1 "BA295610409"', '2 "575480002"', '3 "BANANAL-SP"', '4 "02/03/1959"', '5 "ABUKAMA SOLIS ROZ"', '6 "E;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007446/hipotese.txt
# 66279130482
# 753619394
# 753619394
# CANOCIM DE SÃO FÉLIX-PE
# 07/04/2009
# RN940796798
# ['0 "66279130482"', '1 "753619394"', '2 "753619394"', '3 "CANOCIM DE SÃO FÉLIX-PE"', '4 "07/04/2009"', '5 "RN940796798"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007447/hipotese.txt
# 75994263170
# RS586644116
# 598955230
# GRANITO-PE
# 22/01/1958
# FELIPIN SAMAR
# ['0 "75994263170"', '1 "RS586644116"', '2 "598955230"', '3 "GRANITO-PE"', '4 "22/01/1958"', '5 "FELIPIN SAMAR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007448/hipotese.txt
# 82922843286
# PRO31260293
# 085995693
# MEDINA-MG
# 03/06/2000
# RONDELLO GADY V
# K;
# ['0 "82922843286"', '1 "PRO31260293"', '2 "085995693"', '3 "MEDINA-MG"', '4 "03/06/2000"', '5 "RONDELLO GADY V"', '6 "K;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007449/hipotese.txt
# 37775126855
# MG423022698
# 00974990
# IBIRITÉ-MG
# 17/11/2000
# HERMINIO HIR
# ['0 "37775126855"', '1 "MG423022698"', '2 "00974990"', '3 "IBIRITÉ-MG"', '4 "17/11/2000"', '5 "HERMINIO HIR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007450/hipotese.txt
# 85950160893
# PA070177833
# 80658244
# CARAPEBUS-RJ
# 15/09/1959
# NEDDE CAROL FLAVIA
# ['0 "85950160893"', '1 "PA070177833"', '2 "80658244"', '3 "CARAPEBUS-RJ"', '4 "15/09/1959"', '5 "NEDDE CAROL FLAVIA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007451/hipotese.txt
# 516534014
# 94222756877
# BACABAL-MA
# 28/06/1962
# MISSÃO VALDINEY FEIXOTO
# M;
# ['0 "516534014"', '2 "94222756877"', '3 "BACABAL-MA"', '4 "28/06/1962"', '5 "MISSÃO VALDINEY FEIXOTO"', '6 "M;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007452/hipotese.txt
# 99135346290
# 052491387
# P/588675043
# Pacaraima PR
# 02/10/2008
# Assembleia do Poderão
# ['0 "99135346290"', '1 "052491387"', '2 "P/588675043"', '3 "Pacaraima PR"', '4 "02/10/2008"', '5 "Assembleia do Poderão"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007453/hipotese.txt
# 09845360210
# SP466108435
# 735437002
# PINHEIROS-ES
# 02/04/1993
# AIDA BALDIN VILL SILVEIRA
# B; E;
# ['0 "09845360210"', '1 "SP466108435"', '2 "735437002"', '3 "PINHEIROS-ES"', '4 "02/04/1993"', '5 "AIDA BALDIN VILL SILVEIRA"', '6 "B; E;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007454/hipotese.txt
# 359940481
# 359940481
# DOMINGOS MARTINS-ES
# 28/03/2007
# CARRASCO BOSQUIL 43580458137 SP346667691
# ['0 "359940481"', '2 "359940481"', '3 "DOMINGOS MARTINS-ES"', '4 "28/03/2007"', '5 "CARRASCO BOSQUIL 43580458137 SP346667691"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007455/hipotese.txt
# 720924980
# MT984274123
# 720924980
# RUY BARBOSA-BA
# 08/04/2014
# NAKASAWA ROVERI C
# ['0 "720924980"', '1 "MT984274123"', '2 "720924980"', '3 "RUY BARBOSA-BA"', '4 "08/04/2014"', '5 "NAKASAWA ROVERI C"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007456/hipotese.txt
# 601146601
# 601146601
# PEDRÃO-BA
# 28/12/2009
# CAVAZZANA RÊNAM
# ['1 "601146601"', '2 "601146601"', '3 "PEDRÃO-BA"', '4 "28/12/2009"', '5 "CAVAZZANA RÊNAM"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007457/hipotese.txt
# 631123252
# MT340810994
# 96351867783
# TIANGUÁ-CE
# BAGE-RS
# KAYKO HUSTON TAKITA
# s; Q: D;
# ['0 "631123252"', '1 "MT340810994"', '2 "96351867783"', '3 "TIANGUÁ-CE"', '4 "BAGE-RS"', '5 "KAYKO HUSTON TAKITA"', '6 "s; Q: D;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007458/hipotese.txt
# 915798075
# PE069282046
# 92045418675
# KALORÉ-PR
# 12/06/2011
# CAMILA PELA MIA
# ['0 "915798075"', '1 "PE069282046"', '2 "92045418675"', '3 "KALORÉ-PR"', '4 "12/06/2011"', '5 "CAMILA PELA MIA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007459/hipotese.txt
# 95157827751
# 081481748
# IPERÓ-SP
# 05/01/2011
# ANELLI PEZETA
# ['0 "95157827751"', '1 "081481748"', '3 "IPERÓ-SP"', '4 "05/01/2011"', '5 "ANELLI PEZETA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007460/hipotese.txt
# 81399148826
# AL963202299
# 320301449
# AGRONOMICA-SC
# 01/02/2000
# ['0 "81399148826"', '1 "AL963202299"', '2 "320301449"', '3 "AGRONOMICA-SC"', '4 "01/02/2000"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007461/hipotese.txt
# 740422055
# SP860066914
# 72118648682
# CAMPINORTE-GO
# 16/10/1951
# TORIHARA JEISSIANE
# ['0 "740422055"', '1 "SP860066914"', '2 "72118648682"', '3 "CAMPINORTE-GO"', '4 "16/10/1951"', '5 "TORIHARA JEISSIANE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007462/hipotese.txt
# 74920728153
# 58010193
# 658010193
# LUCÉLIA-SP
# 13/09/1982
# TURBUK PIAS
# ['0 "74920728153"', '1 "58010193"', '2 "658010193"', '3 "LUCÉLIA-SP"', '4 "13/09/1982"', '5 "TURBUK PIAS"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007463/hipotese.txt
# 12650809
# MG443151208
# 60416534982
# PARAISO-SC
# 08/07/1960
# E.FERREIRA KOSENOR
# ['0 "12650809"', '1 "MG443151208"', '2 "60416534982"', '3 "PARAISO-SC"', '4 "08/07/1960"', '5 "E.FERREIRA KOSENOR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007464/hipotese.txt
# 645192262924
# 640819209
# JOSÉ DE FREITAS-PI
# 14/07/1958
# PETERSON MEC
# ['0 "645192262924"', '1 "640819209"', '3 "JOSÉ DE FREITAS-PI"', '4 "14/07/1958"', '5 "PETERSON MEC"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007465/hipotese.txt
# 01367991534
# RN108687707
# 987903720
# CERES-GO
# 30/01/2015
# JUNIA WIDNIC
# ['0 "01367991534"', '1 "RN108687707"', '2 "987903720"', '3 "CERES-GO"', '4 "30/01/2015"', '5 "JUNIA WIDNIC"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007466/hipotese.txt
# 09668243436
# CE006374344
# 322501764
# TESOURO-MT
# 11/01/1973
# BONOMI SENTO NO
# ['0 "09668243436"', '1 "CE006374344"', '2 "322501764"', '3 "TESOURO-MT"', '4 "11/01/1973"', '5 "BONOMI SENTO NO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007467/hipotese.txt
# 434913068
# NOVA FÁTIMA-BA
# 29/10/2004
# SOPHIA THIESEN CA
# ['1 "434913068"', '3 "NOVA FÁTIMA-BA"', '4 "29/10/2004"', '5 "SOPHIA THIESEN CA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007468/hipotese.txt
# 22031949772
# PR852278801
# 7973487
# ITATINGA-SP
# 05/11/2007
# DELSON MAS MARLEI
# ['0 "22031949772"', '1 "PR852278801"', '2 "7973487"', '3 "ITATINGA-SP"', '4 "05/11/2007"', '5 "DELSON MAS MARLEI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007469/hipotese.txt
# 42191795609
# G088405221
# 824668699
# LADAINHA-MG
# 04/09/1961
# GERONIMO MARTINI
# ['0 "42191795609"', '1 "G088405221"', '2 "824668699"', '3 "LADAINHA-MG"', '4 "04/09/1961"', '5 "GERONIMO MARTINI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007470/hipotese.txt
# 69578944394
# SP010489971
# 800418534
# ARARICÁ-RS
# 01/01/1957
# RAGASSI BOSQUE
# ['0 "69578944394"', '1 "SP010489971"', '2 "800418534"', '3 "ARARICÁ-RS"', '4 "01/01/1957"', '5 "RAGASSI BOSQUE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007471/hipotese.txt
# 93560167083
# SP747847286
# 752678692
# JAPI-RN
# 28/10/1994
# KAROL MILONE
# ['0 "93560167083"', '1 "SP747847286"', '2 "752678692"', '3 "JAPI-RN"', '4 "28/10/1994"', '5 "KAROL MILONE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007472/hipotese.txt
# 575480002
# BA295610409
# 30188729431
# BANANAL-SP
# 02/03/1959
# ABUKAW. SOLIS ROV
# E;
# ['0 "575480002"', '1 "BA295610409"', '2 "30188729431"', '3 "BANANAL-SP"', '4 "02/03/1959"', '5 "ABUKAW. SOLIS ROV"', '6 "E;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007473/hipotese.txt
# 920454198673
# P0609282046
# 1579075
# KALCÓRE-PR
# 12/06/2011
# CAMILA PELA MIA
# ['0 "920454198673"', '1 "P0609282046"', '2 "1579075"', '3 "KALCÓRE-PR"', '4 "12/06/2011"', '5 "CAMILA PELA MIA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007474/hipotese.txt
# 321991964
# BA768942653
# 4994964
# MURIBECA-SE
# 11/02/1963
# LAURA JANI MORETI
# ['0 "321991964"', '1 "BA768942653"', '2 "4994964"', '3 "MURIBECA-SE"', '4 "11/02/1963"', '5 "LAURA JANI MORETI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007475/hipotese.txt
# 842631154
# W;
# MANAQUIRI-AM
# 18/11/2008
# SUFLEY RISSARDI
# PF399545646
# ['0 "842631154"', '1 "W;"', '3 "MANAQUIRI-AM"', '4 "18/11/2008"', '5 "SUFLEY RISSARDI"', '6 "PF399545646"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007476/hipotese.txt
# 05773365015
# CE55693302
# 645309434
# ANAHY-PR
# 20/03/1993
# LIOR CONSOL
# ['0 "05773365015"', '1 "CE55693302"', '2 "645309434"', '3 "ANAHY-PR"', '4 "20/03/1993"', '5 "LIOR CONSOL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007477/hipotese.txt
# 21992172188
# BA070238988
# 331273053
# Aquidabá-SE
# 05/12/1978
# Trevisani Far
# ['0 "21992172188"', '1 "BA070238988"', '2 "331273053"', '3 "Aquidabá-SE"', '4 "05/12/1978"', '5 "Trevisani Far"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007478/hipotese.txt
# 50586071713
# M320312048
# 954323165
# TACIBA-SP
# 19/11/1953
# ADALIR MAZELLI
# P; C; C;
# ['0 "50586071713"', '1 "M320312048"', '2 "954323165"', '3 "TACIBA-SP"', '4 "19/11/1953"', '5 "ADALIR MAZELLI"', '6 "P; C; C;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007479/hipotese.txt
# 661987441
# 91234753965
# 661987441
# COIVARAS-PI
# 14/11/1954
# EURO PASOTTO
# ['0 "661987441"', '1 "91234753965"', '2 "661987441"', '3 "COIVARAS-PI"', '4 "14/11/1954"', '5 "EURO PASOTTO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007480/hipotese.txt
# 90426324069
# BA781063768
# 923322371
# CUPARACU-MG
# 23/03/1997
# RAGAZINE KRISTHIAN CAMPOS
# V ;
# ['0 "90426324069"', '1 "BA781063768"', '2 "923322371"', '3 "CUPARACU-MG"', '4 "23/03/1997"', '5 "RAGAZINE KRISTHIAN CAMPOS"', '6 "V ;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007481/hipotese.txt
# 667352071
# RJ56164598
# 89792156425
# ITIUBA-BA
# 26/10/1959
# TRIEUZZI FLAVIAN DA LUZ
# ['0 "667352071"', '1 "RJ56164598"', '2 "89792156425"', '3 "ITIUBA-BA"', '4 "26/10/1959"', '5 "TRIEUZZI FLAVIAN DA LUZ"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007482/hipotese.txt
# 85676610422
# GO656694437
# 60521632
# MARCELÂNDIA-MT
# 10/01/2007
# LEOANA NINOMIY
# ['0 "85676610422"', '1 "GO656694437"', '2 "60521632"', '3 "MARCELÂNDIA-MT"', '4 "10/01/2007"', '5 "LEOANA NINOMIY"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007483/hipotese.txt
# 88112494460
# MG024198517
# 454563287
# MALLET-PR
# MASTROBUONO CARAM FERNANDES
# K;
# ['0 "88112494460"', '1 "MG024198517"', '2 "454563287"', '3 "MALLET-PR"', '5 "MASTROBUONO CARAM FERNANDES"', '6 "K;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007484/hipotese.txt
# 72294046512
# 322533317
# CUIABA-MT
# 21/04/2018
# SAGLIETTI S
# ['0 "72294046512"', '1 "322533317"', '3 "CUIABA-MT"', '4 "21/04/2018"', '5 "SAGLIETTI S"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007485/hipotese.txt
# 55619403683
# R0347185401
# 340748385
# IMBITUVA-PR
# 06/01/1983
# CERETO CHEI
# ['0 "55619403683"', '1 "R0347185401"', '2 "340748385"', '3 "IMBITUVA-PR"', '4 "06/01/1983"', '5 "CERETO CHEI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007486/hipotese.txt
# 144563058
# PR473012389
# 12296401494
# CORUMBÁ-MS
# PALMA-MG
# MICAI ORJANA ERINCA
# X; P: I;
# ['0 "144563058"', '1 "PR473012389"', '2 "12296401494"', '3 "CORUMBÁ-MS"', '4 "PALMA-MG"', '5 "MICAI ORJANA ERINCA"', '6 "X; P: I;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007487/hipotese.txt
# 858767800
# RN343210610
# 24334389554
# QUATA-SP
# GOIANA-PE
# CTUBO POIANI MAJIMA
# EXERCE ATIVIDADE REMUNERADA;
# ['0 "858767800"', '1 "RN343210610"', '2 "24334389554"', '3 "QUATA-SP"', '4 "GOIANA-PE"', '5 "CTUBO POIANI MAJIMA"', '6 "EXERCE ATIVIDADE REMUNERADA;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007488/hipotese.txt
# 68298070269
# SP996560468
# 62881177
# CONTENDA-PR
# 31/10/1985
# DALIA TROCOLI VIEIRA
# ['0 "68298070269"', '1 "SP996560468"', '2 "62881177"', '3 "CONTENDA-PR"', '4 "31/10/1985"', '5 "DALIA TROCOLI VIEIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007489/hipotese.txt
# 84541811657
# MG390039724
# 055834969
# MATRINCHA-GO
# 07/03/1967
# SHIGUEAKI YKE
# ['0 "84541811657"', '1 "MG390039724"', '2 "055834969"', '3 "MATRINCHA-GO"', '4 "07/03/1967"', '5 "SHIGUEAKI YKE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007490/hipotese.txt
# 98979630860
# 269073593
# 269073593
# EXU-PE
# 06/06/1950
# MASUCHELLI OD
# EXERCE ATIVIDADE REMUNERADA: A; EXERCE ATIVIDADE REMUNERADA;
# ['0 "98979630860"', '1 "269073593"', '2 "269073593"', '3 "EXU-PE"', '4 "06/06/1950"', '5 "MASUCHELLI OD"', '6 "EXERCE ATIVIDADE REMUNERADA: A; EXERCE ATIVIDADE REMUNERADA;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007491/hipotese.txt
# 561342023
# 561342023
# ITAPE-BA
# 20/04/2004
# STAMATO KELLEN MANAI 066293230232
# ['1 "561342023"', '2 "561342023"', '3 "ITAPE-BA"', '4 "20/04/2004"', '5 "STAMATO KELLEN MANAI 066293230232"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007492/hipotese.txt
# 582776286
# TRINDADE-PE
# 29/12/1955
# MANFREDINE KAWAO
# ['1 "582776286"', '3 "TRINDADE-PE"', '4 "29/12/1955"', '5 "MANFREDINE KAWAO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007493/hipotese.txt
# 180672790
# SP024040633
# 86865158935
# NHAMUNDÁ-AM
# 30/08/1968
# MASSADY FELUCI
# ['0 "180672790"', '1 "SP024040633"', '2 "86865158935"', '3 "NHAMUNDÁ-AM"', '4 "30/08/1968"', '5 "MASSADY FELUCI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007494/hipotese.txt
# 3219196800
# SP775829671
# 1916800
# CORUMBÁIBA-GO
# 26/11/2020
# VASQUES KRIESEL C FREITAS
# ['0 "3219196800"', '1 "SP775829671"', '2 "1916800"', '3 "CORUMBÁIBA-GO"', '4 "26/11/2020"', '5 "VASQUES KRIESEL C FREITAS"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007495/hipotese.txt
# 213521806
# ER728505486
# FELIZ-RS
# 19/04/1979
# DURBANO SAVVA TO
# ['0 "213521806"', '1 "ER728505486"', '3 "FELIZ-RS"', '4 "19/04/1979"', '5 "DURBANO SAVVA TO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007496/hipotese.txt
# 35878636073
# 07257119
# 07257119
# AROAIZES-PI
# 26/09/1962
# MASSUITI VE
# ['0 "35878636073"', '1 "07257119"', '2 "07257119"', '3 "AROAIZES-PI"', '4 "26/09/1962"', '5 "MASSUITI VE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007497/hipotese.txt
# 180627474746
# PE962240686
# 702835963
# IRECE-BA
# 05/05/1980
# POLATO CLAYTON BICA
# ['0 "180627474746"', '1 "PE962240686"', '2 "702835963"', '3 "IRECE-BA"', '4 "05/05/1980"', '5 "POLATO CLAYTON BICA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007498/hipotese.txt
# 37761128
# 30284964165
# 37761128
# DIVINESIA-MG
# 20/12/2003
# ARENDA EIKA
# ['0 "37761128"', '1 "30284964165"', '2 "37761128"', '3 "DIVINESIA-MG"', '4 "20/12/2003"', '5 "ARENDA EIKA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007499/hipotese.txt
# 953400040
# 49638587406
# 953400040
# SEARA-SC
# 14/09/1996
# LUCENTE IMPROTA PEL
# ['0 "953400040"', '1 "49638587406"', '2 "953400040"', '3 "SEARA-SC"', '4 "14/09/1996"', '5 "LUCENTE IMPROTA PEL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007500/hipotese.txt
# 86784785803
# PB244567910
# 672051803
# UBERABA-MG
# 13/12/1976
# GISLEINE LA
# ['0 "86784785803"', '1 "PB244567910"', '2 "672051803"', '3 "UBERABA-MG"', '4 "13/12/1976"', '5 "GISLEINE LA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007501/hipotese.txt
# 835771323
# MONTEZUMA-MG
# 02/12/1959
# TELEFONEM SOMER DAS NEVES
# ['1 "835771323"', '3 "MONTEZUMA-MG"', '4 "02/12/1959"', '5 "TELEFONEM SOMER DAS NEVES"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007502/hipotese.txt
# 56114572057
# 325110183
# ARUJÁ-SP
# 05/05/1988
# MATTIO NAKID
# ['0 "56114572057"', '1 "325110183"', '3 "ARUJÁ-SP"', '4 "05/05/1988"', '5 "MATTIO NAKID"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007503/hipotese.txt
# 135932296
# 845273560604
# 135932296
# ITAOCARA-RJ
# 19/05/1954
# ASSINATURA DO EMISSOR
# ['0 "135932296"', '1 "845273560604"', '2 "135932296"', '3 "ITAOCARA-RJ"', '4 "19/05/1954"', '5 "ASSINATURA DO EMISSOR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007504/hipotese.txt
# 492106358
# MS243081588
# 98319315290
# NOVAIS-SP
# 02/10/2001
# ILEANA FUNARI J
# ['0 "492106358"', '1 "MS243081588"', '2 "98319315290"', '3 "NOVAIS-SP"', '4 "02/10/2001"', '5 "ILEANA FUNARI J"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007505/hipotese.txt
# 262276929569
# 931204593
# AB123456789
# APARECIDA - SF
# 20/09/1991
# IMPARATO RHA
# ['0 "262276929569"', '1 "931204593"', '2 "AB123456789"', '3 "APARECIDA - SF"', '4 "20/09/1991"', '5 "IMPARATO RHA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007506/hipotese.txt
# 786538964
# BA400894946
# 24827424499
# VARZEA-PB
# 12/11/1971
# ZUGAR LEITE SORRA
# ['0 "786538964"', '1 "BA400894946"', '2 "24827424499"', '3 "VARZEA-PB"', '4 "12/11/1971"', '5 "ZUGAR LEITE SORRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007507/hipotese.txt
# 13774140921
# MC34558278
# 44203680
# NOVA FLORESTA-PB
# 24/12/1999
# ['0 "13774140921"', '1 "MC34558278"', '2 "44203680"', '3 "NOVA FLORESTA-PB"', '4 "24/12/1999"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007508/hipotese.txt
# 94367546191
# MG941830627
# 605810811
# MIRANDA-MS
# 18/11/2000
# FINCATO SAMANTA BOL
# ['0 "94367546191"', '1 "MG941830627"', '2 "605810811"', '3 "MIRANDA-MS"', '4 "18/11/2000"', '5 "FINCATO SAMANTA BOL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007509/hipotese.txt
# 507636162
# 42948284469
# 507636162
# FUNDAO-ES
# 06/03/1965
# FRANCYELLY C
# ['0 "507636162"', '1 "42948284469"', '2 "507636162"', '3 "FUNDAO-ES"', '4 "06/03/1965"', '5 "FRANCYELLY C"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007510/hipotese.txt
# 83428326473
# PE511205865
# 350722271
# MARAPOAMA-SP
# 08/06/1983
# GRAVITO RODGE
# ['0 "83428326473"', '1 "PE511205865"', '2 "350722271"', '3 "MARAPOAMA-SP"', '4 "08/06/1983"', '5 "GRAVITO RODGE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007511/hipotese.txt
# 30073745432
# BA125670990
# 958410557
# CHOROZINHO-CE
# 19/03/1989
# DETRAN MG (MINAS GERAIS)
# ['0 "30073745432"', '1 "BA125670990"', '2 "958410557"', '3 "CHOROZINHO-CE"', '4 "19/03/1989"', '5 "DETRAN MG (MINAS GERAIS)"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007512/hipotese.txt
# 476337390
# PE512491868
# 17433820106
# JATOBÁ-PE
# 19/04/1964
# GROMATUXI GALLIOTE C2
# ['0 "476337390"', '1 "PE512491868"', '2 "17433820106"', '3 "JATOBÁ-PE"', '4 "19/04/1964"', '5 "GROMATUXI GALLIOTE C2"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007513/hipotese.txt
# 90337364970
# 64538152
# GUACUÍ-ES
# 05/04/1987
# IMÃ José Caio Gle
# ['0 "90337364970"', '1 "64538152"', '3 "GUACUÍ-ES"', '4 "05/04/1987"', '5 "IMÃ José Caio Gle"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007514/hipotese.txt
# 024092150
# ITAGUAÍ-RJ
# 23/04/1984
# ALEXSANDRO KOETA
# ['1 "024092150"', '3 "ITAGUAÍ-RJ"', '4 "23/04/1984"', '5 "ALEXSANDRO KOETA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007515/hipotese.txt
# 534935425
# PR097975160
# 534935425
# SÃO JOÃO DEL REI-MG
# 18/09/1969
# SPACOV ZUGLIANI TIN 51063167945
# ['0 "534935425"', '1 "PR097975160"', '2 "534935425"', '3 "SÃO JOÃO DEL REI-MG"', '4 "18/09/1969"', '5 "SPACOV ZUGLIANI TIN 51063167945"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007516/hipotese.txt
# 81149527145
# PK684646332
# 741304451
# CAÉM-BA
# 02/02/1990
# BOZZINI EDNEI VI CALEBIRA
# ['0 "81149527145"', '1 "PK684646332"', '2 "741304451"', '3 "CAÉM-BA"', '4 "02/02/1990"', '5 "BOZZINI EDNEI VI CALEBIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007517/hipotese.txt
# 723568709535
# PE274155575
# 377809900
# LUNA-ES
# 12/10/1982
# SHYH IANOVALI V
# Y
# ['0 "723568709535"', '1 "PE274155575"', '2 "377809900"', '3 "LUNA-ES"', '4 "12/10/1982"', '5 "SHYH IANOVALI V"', '6 "Y"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007518/hipotese.txt
# 621186674
# 62229625925
# 621186674
# ...
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007913/hipotese.txt
# 89913546290
# PR888750436
# 052491387
# APUCARANA, PR
# 02/10/2008
# DETRAN PR (PARANA)
# ['0 "89913546290"', '1 "PR888750436"', '2 "052491387"', '3 "APUCARANA, PR"', '4 "02/10/2008"', '5 "DETRAN PR (PARANA)"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007914/hipotese.txt
# 92450976705
# PR863193423
# 135065820
# SÃO MANOEL DO PARANÁ-PR
# 27/10/1962
# GRAJEW LOCUER
# ['0 "92450976705"', '1 "PR863193423"', '2 "135065820"', '3 "SÃO MANOEL DO PARANÁ-PR"', '4 "27/10/1962"', '5 "GRAJEW LOCUER"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007915/hipotese.txt
# 72284553
# 72284553
# IPUMIRIM-SC
# 11/06/1979
# PETKEVICIUS SACC
# ['1 "72284553"', '2 "72284553"', '3 "IPUMIRIM-SC"', '4 "11/06/1979"', '5 "PETKEVICIUS SACC"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007916/hipotese.txt
# 169542723
# MORRINHOS-CE
# 18/10/1985
# MONTES TERUKAZU VITH 480455943539 RS420512583
# ['1 "169542723"', '3 "MORRINHOS-CE"', '4 "18/10/1985"', '5 "MONTES TERUKAZU VITH 480455943539 RS420512583"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007917/hipotese.txt
# 1429814068
# RS456007078
# 426420531
# ARAGUATINS-TO
# 12/03/1950
# JOSILAINE SUGHWAN RAMOS
# J;
# ['0 "1429814068"', '1 "RS456007078"', '2 "426420531"', '3 "ARAGUATINS-TO"', '4 "12/03/1950"', '5 "JOSILAINE SUGHWAN RAMOS"', '6 "J;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007918/hipotese.txt
# 72720270
# 48718601735
# ARACAGI-PB
# 20/11/1972
# GULA SINJIN ALOI
# N; G; Y; EXERCE ATIVIDADE REMUNERADA;
# ['1 "72720270"', '2 "48718601735"', '3 "ARACAGI-PB"', '4 "20/11/1972"', '5 "GULA SINJIN ALOI"', '6 "N; G; Y; EXERCE ATIVIDADE REMUNERADA;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007919/hipotese.txt
# 76005210408
# 059015351
# PALESTINA-SP
# 17/10/1980
# KATAGUIRI ISHURA AS
# ['0 "76005210408"', '1 "059015351"', '3 "PALESTINA-SP"', '4 "17/10/1980"', '5 "KATAGUIRI ISHURA AS"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007920/hipotese.txt
# 95346526650
# 9743186
# ASCURRA-SC
# 31/03/2001
# BENDICT HENRIQUE RODRIGUES
# ['0 "95346526650"', '1 "9743186"', '3 "ASCURRA-SC"', '4 "31/03/2001"', '5 "BENDICT HENRIQUE RODRIGUES"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007921/hipotese.txt
# 55810062975
# SE511435182
# 526299640
# JACUPIRANGA-SP
# 16/01/1990
# CIRINO FRANCELI ALVES
# ['0 "55810062975"', '1 "SE511435182"', '2 "526299640"', '3 "JACUPIRANGA-SP"', '4 "16/01/1990"', '5 "CIRINO FRANCELI ALVES"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007922/hipotese.txt
# 32709356561
# PA732598068
# 491788411
# PIO XII-MA
# 17/08/2008
# MALZONI BEN
# ['0 "32709356561"', '1 "PA732598068"', '2 "491788411"', '3 "PIO XII-MA"', '4 "17/08/2008"', '5 "MALZONI BEN"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007923/hipotese.txt
# 073923298
# 9083457846
# SOURE-PA
# 21/08/1955
# ELIESER POLIT
# ['1 "073923298"', '2 "9083457846"', '3 "SOURE-PA"', '4 "21/08/1955"', '5 "ELIESER POLIT"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007924/hipotese.txt
# 291614000
# PI856264944
# 86590161669
# ITÁ-SC
# 12/01/1972
# ONOFRE PESSE
# ['0 "291614000"', '1 "PI856264944"', '2 "86590161669"', '3 "ITÁ-SC"', '4 "12/01/1972"', '5 "ONOFRE PESSE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007925/hipotese.txt
# 40520333013
# BA216455199
# 107769543
# BOM JESUS-SC
# 14/07/1975
# P;
# ['0 "40520333013"', '1 "BA216455199"', '2 "107769543"', '3 "BOM JESUS-SC"', '4 "14/07/1975"', '6 "P;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007926/hipotese.txt
# 68289070269
# SP996540468
# 62891177
# CONTENDA-PR
# 31/10/1985
# VISITA
# ['0 "68289070269"', '1 "SP996540468"', '2 "62891177"', '3 "CONTENDA-PR"', '4 "31/10/1985"', '6 "VISITA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007927/hipotese.txt
# 05773365015
# 645309434
# ANAHY-PR
# 20/03/1993
# LIOR CONSOL
# ['0 "05773365015"', '1 "645309434"', '3 "ANAHY-PR"', '4 "20/03/1993"', '5 "LIOR CONSOL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007928/hipotese.txt
# 09846154138
# PI062612039
# 682092435
# ITATIRA-CE
# 25/12/1978
# MITUI VOGELAAR
# ['0 "09846154138"', '1 "PI062612039"', '2 "682092435"', '3 "ITATIRA-CE"', '4 "25/12/1978"', '5 "MITUI VOGELAAR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007929/hipotese.txt
# 381561325
# T;
# JEREMOABO-BA
# 03/10/1958
# LICIANE RUDA GAT
# ['1 "381561325"', '2 "T;"', '3 "JEREMOABO-BA"', '4 "03/10/1958"', '5 "LICIANE RUDA GAT"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007930/hipotese.txt
# 29533565424
# SC433905426
# 472879828
# NOVA GLÓRIA-GO
# 02/03/1971
# ALTMAYER ERICA E
# ['0 "29533565424"', '1 "SC433905426"', '2 "472879828"', '3 "NOVA GLÓRIA-GO"', '4 "02/03/1971"', '5 "ALTMAYER ERICA E"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007931/hipotese.txt
# 144563058
# CORUMBÁ-MS
# PALMA-MG
# MICAI ORJANA ENINCA
# X; P; I;
# ['0 "144563058"', '3 "CORUMBÁ-MS"', '4 "PALMA-MG"', '5 "MICAI ORJANA ENINCA"', '6 "X; P; I;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007932/hipotese.txt
# 27072607588
# BA338404532
# 262457043
# JUSCIMEIRA-MT
# 06/09/1956
# VENDRAMIN NAV
# ['0 "27072607588"', '1 "BA338404532"', '2 "262457043"', '3 "JUSCIMEIRA-MT"', '4 "06/09/1956"', '5 "VENDRAMIN NAV"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007933/hipotese.txt
# 373601834
# 61432734576
# CJARATI-MA
# 04/06/1961
# RODOVÁLHO DELB
# DETRAN MG MINAS GERAIS
# ['1 "373601834"', '2 "61432734576"', '3 "CJARATI-MA"', '4 "04/06/1961"', '5 "RODOVÁLHO DELB"', '6 "DETRAN MG MINAS GERAIS"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007934/hipotese.txt
# 331411155234
# 838420450
# RIO POMBA-MG
# 19/02/1971
# LESSIO OSVALDIR VOI
# ['0 "331411155234"', '1 "838420450"', '3 "RIO POMBA-MG"', '4 "19/02/1971"', '5 "LESSIO OSVALDIR VOI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007935/hipotese.txt
# 88171989117
# PB998087750
# 212915602
# ROTEIRO-AL
# 11/08/1983
# DAQUINO CAWAM
# Y ; J ;
# ['0 "88171989117"', '1 "PB998087750"', '2 "212915602"', '3 "ROTEIRO-AL"', '4 "11/08/1983"', '5 "DAQUINO CAWAM"', '6 "Y ; J ;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007936/hipotese.txt
# 06629323032
# PRG37550291
# 561342023
# ITAPÉ-BA
# 20/04/2004
# STAMATO KELLEN MANAI
# ['0 "06629323032"', '1 "PRG37550291"', '2 "561342023"', '3 "ITAPÉ-BA"', '4 "20/04/2004"', '5 "STAMATO KELLEN MANAI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007937/hipotese.txt
# 05083336801
# MG6719800070
# 603395875
# ROTEIRO-AL
# 07/03/1983
# NATALHA CARM
# ['0 "05083336801"', '1 "MG6719800070"', '2 "603395875"', '3 "ROTEIRO-AL"', '4 "07/03/1983"', '5 "NATALHA CARM"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007938/hipotese.txt
# 364110576
# BA704299188
# 29692883465
# ITAGIBÁ-BA
# 13/12/2011
# LAURINDA QUELHO
# F;
# ['0 "364110576"', '1 "BA704299188"', '2 "29692883465"', '3 "ITAGIBÁ-BA"', '4 "13/12/2011"', '5 "LAURINDA QUELHO"', '6 "F;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007939/hipotese.txt
# 261004499
# ITIRAPINA-SP
# 09/05/1955
# KATIA NARA APANI
# ['1 "261004499"', '3 "ITIRAPINA-SP"', '4 "09/05/1955"', '5 "KATIA NARA APANI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007940/hipotese.txt
# 133316551
# PINHAIS-PR
# 31/07/1986
# MIYATAKE CONTA
# ['1 "133316551"', '3 "PINHAIS-PR"', '4 "31/07/1986"', '5 "MIYATAKE CONTA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007941/hipotese.txt
# 97372573765
# 748398250
# CAMOCIM-CE
# 30/07/1993
# MALPELI SCEME
# ['0 "97372573765"', '1 "748398250"', '3 "CAMOCIM-CE"', '4 "30/07/1993"', '5 "MALPELI SCEME"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007942/hipotese.txt
# 65767084370
# MA076734636
# 220269309
# PUTINGA-RS
# 21/12/1952
# NIUTON VIGO SU
# ['0 "65767084370"', '1 "MA076734636"', '2 "220269309"', '3 "PUTINGA-RS"', '4 "21/12/1952"', '5 "NIUTON VIGO SU"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007943/hipotese.txt
# 624822220242
# SP437273288
# 419677702
# AFRANIO-PE
# 30/10/2010
# ['0 "624822220242"', '1 "SP437273288"', '2 "419677702"', '3 "AFRANIO-PE"', '4 "30/10/2010"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007944/hipotese.txt
# 69578944394
# SP010489971
# 800418534
# ARARICÁ-RS
# 01/01/1957
# RAGASSI BOSQUE
# ['0 "69578944394"', '1 "SP010489971"', '2 "800418534"', '3 "ARARICÁ-RS"', '4 "01/01/1957"', '5 "RAGASSI BOSQUE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007945/hipotese.txt
# 94222756877
# 516534014
# EASCARAL-MA
# 28/05/1962
# ASSINATURA DO EMISSOR
# M ;
# ['0 "94222756877"', '1 "516534014"', '3 "EASCARAL-MA"', '4 "28/05/1962"', '5 "ASSINATURA DO EMISSOR"', '6 "M ;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007946/hipotese.txt
# 29098953882
# MG406189695
# 913279966
# SEBERI-RS
# 19/07/1996
# MENDEZ TURCATO
# N;
# ['0 "29098953882"', '1 "MG406189695"', '2 "913279966"', '3 "SEBERI-RS"', '4 "19/07/1996"', '5 "MENDEZ TURCATO"', '6 "N;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007947/hipotese.txt
# 588919702
# 20228121967
# 588919702
# VILA BOA-GO
# 25/12/1996
# SPATTI FABIANO
# ['0 "588919702"', '1 "20228121967"', '2 "588919702"', '3 "VILA BOA-GO"', '4 "25/12/1996"', '5 "SPATTI FABIANO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007948/hipotese.txt
# 70185356151
# 757837230
# MIRADOR-MA
# 04/10/2016
# JANSSEN MASET
# PROIBIDO PLASTIFICAR
# ['0 "70185356151"', '1 "757837230"', '3 "MIRADOR-MA"', '4 "04/10/2016"', '5 "JANSSEN MASET"', '6 "PROIBIDO PLASTIFICAR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007949/hipotese.txt
# 417350315
# MOEDA-MG
# 31/12/1987
# FALCIN PANHOCA GIA
# B;
# ['1 "417350315"', '3 "MOEDA-MG"', '4 "31/12/1987"', '5 "FALCIN PANHOCA GIA"', '6 "B;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007950/hipotese.txt
# 94367546191
# MG941830627
# 605810811
# MIRANDA-MS
# 18/11/2000
# FINCATO SAMANTA BOL
# ['0 "94367546191"', '1 "MG941830627"', '2 "605810811"', '3 "MIRANDA-MS"', '4 "18/11/2000"', '5 "FINCATO SAMANTA BOL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007951/hipotese.txt
# 565749013382
# R0513966298
# 597511977
# ITAJA-GO
# 10/04/1979
# SEBYAKU WEL
# ['0 "565749013382"', '1 "R0513966298"', '2 "597511977"', '3 "ITAJA-GO"', '4 "10/04/1979"', '5 "SEBYAKU WEL"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007952/hipotese.txt
# 24500985479
# BA296506927
# 65964119
# URUOCA-CE
# 04/08/1967
# HOLZHACKER BIGA
# V;
# ['0 "24500985479"', '1 "BA296506927"', '2 "65964119"', '3 "URUOCA-CE"', '4 "04/08/1967"', '5 "HOLZHACKER BIGA"', '6 "V;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007953/hipotese.txt
# 99964090128
# MG431519658
# 972566279
# CAMPO DO TENENTE-PR
# 26/11/1980
# DERISSO BOTAS TEIXEIRA
# ['0 "99964090128"', '1 "MG431519658"', '2 "972566279"', '3 "CAMPO DO TENENTE-PR"', '4 "26/11/1980"', '5 "DERISSO BOTAS TEIXEIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007954/hipotese.txt
# 741304451
# PX684646332
# 741304451
# CAEM-BA
# 02/02/1990
# BOZZINI EDNEI VI CALDEIRA
# ['0 "741304451"', '1 "PX684646332"', '2 "741304451"', '3 "CAEM-BA"', '4 "02/02/1990"', '5 "BOZZINI EDNEI VI CALDEIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007955/hipotese.txt
# 725205767
# PB773715628
# 97418843906
# TAMARANA-PR
# 06/07/2007
# MANAI BENEDI
# ['0 "725205767"', '1 "PB773715628"', '2 "97418843906"', '3 "TAMARANA-PR"', '4 "06/07/2007"', '5 "MANAI BENEDI"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007956/hipotese.txt
# 00153876605
# G0629674569
# 318246020
# MARQUINHO-PR
# 06/01/1956
# TAGORE BISTRICHE
# ['0 "00153876605"', '1 "G0629674569"', '2 "318246020"', '3 "MARQUINHO-PR"', '4 "06/01/1956"', '5 "TAGORE BISTRICHE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007957/hipotese.txt
# 13540205362
# SP477917537
# 291524057
# CAMAMU-BA
# 30/04/1989
# X ;
# ['0 "13540205362"', '1 "SP477917537"', '2 "291524057"', '3 "CAMAMU-BA"', '4 "30/04/1989"', '6 "X ;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007958/hipotese.txt
# 9888715930
# 052491387
# Pacuçara PR
# 02/10/2008
# Assinatura do emissor
# ['0 "9888715930"', '1 "052491387"', '3 "Pacuçara PR"', '4 "02/10/2008"', '5 "Assinatura do emissor"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007959/hipotese.txt
# 89913546290
# PR888750436
# 052491387
# APUCARANA, PR
# 02/10/2008
# ['0 "89913546290"', '1 "PR888750436"', '2 "052491387"', '3 "APUCARANA, PR"', '4 "02/10/2008"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007960/hipotese.txt
# 18652321354
# SP794321232
# 560345657
# IKUPI ES
# 27/06/1994
# TAMEDURUS GO
# ['0 "18652321354"', '1 "SP794321232"', '2 "560345657"', '3 "IKUPI ES"', '4 "27/06/1994"', '5 "TAMEDURUS GO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007961/hipotese.txt
# 976969231
# COLINAS-MA
# 03/07/2008
# SUGIMATY WRIG FERREIRA
# ['1 "976969231"', '3 "COLINAS-MA"', '4 "03/07/2008"', '5 "SUGIMATY WRIG FERREIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007962/hipotese.txt
# 00153876605
# G0629674569
# 318246020
# MARQUINHO-PR
# 06/01/1956
# TAGORE BISTRICHE
# ['0 "00153876605"', '1 "G0629674569"', '2 "318246020"', '3 "MARQUINHO-PR"', '4 "06/01/1956"', '5 "TAGORE BISTRICHE"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007963/hipotese.txt
# 28809516824
# MG609616557
# 347632013
# GUAÍPA-PR
# 22/12/2015
# NASSIM AUD CIC
# ['0 "28809516824"', '1 "MG609616557"', '2 "347632013"', '3 "GUAÍPA-PR"', '4 "22/12/2015"', '5 "NASSIM AUD CIC"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007964/hipotese.txt
# 02116857345
# PT755976337
# 461827152
# GOIANIA-GO
# 09/02/1954
# I.
# ['0 "02116857345"', '1 "PT755976337"', '2 "461827152"', '3 "GOIANIA-GO"', '4 "09/02/1954"', '6 "I."']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007965/hipotese.txt
# 42070385635
# SE460639922
# 353678595
# ITALVA-RJ
# 18/04/1951
# SIA BUNCANA J
# Y;
# ['0 "42070385635"', '1 "SE460639922"', '2 "353678595"', '3 "ITALVA-RJ"', '4 "18/04/1951"', '5 "SIA BUNCANA J"', '6 "Y;"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007966/hipotese.txt
# 74175619405
# MG506945169
# 595648557
# UNAI - MG
# 20/02/1970
# DETRAN PR (PARANÁ)
# ['0 "74175619405"', '1 "MG506945169"', '2 "595648557"', '3 "UNAI - MG"', '4 "20/02/1970"', '5 "DETRAN PR (PARANÁ)"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007967/hipotese.txt
# 2053351101
# PR845177650
# 65316521797
# IPIRANGA DO SUL-RS
# PITALUGA TABA
# ['0 "2053351101"', '1 "PR845177650"', '2 "65316521797"', '3 "IPIRANGA DO SUL-RS"', '5 "PITALUGA TABA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007968/hipotese.txt
# 47581950170
# 529400870
# JARDIM-CE
# 12/07/1962
# FUJIKAZU KIYAN
# ['0 "47581950170"', '1 "529400870"', '3 "JARDIM-CE"', '4 "12/07/1962"', '5 "FUJIKAZU KIYAN"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007969/hipotese.txt
# 418381153
# SC768004967
# 96257938253
# ITAPUCA-RS
# 05/08/2003
# ANALUCIA BUENO
# ['0 "418381153"', '1 "SC768004967"', '2 "96257938253"', '3 "ITAPUCA-RS"', '4 "05/08/2003"', '5 "ANALUCIA BUENO"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007970/hipotese.txt
# 03112015772
# SP846107217
# 175946567
# CUMARI-GO
# 14/05/1990
# GUINOZA PANE WA.
# ['0 "03112015772"', '1 "SP846107217"', '2 "175946567"', '3 "CUMARI-GO"', '4 "14/05/1990"', '5 "GUINOZA PANE WA."']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007971/hipotese.txt
# 524020589
# 524020589
# GUARANHOB
# 25/09/1975
# ['0 "524020589"', '1 "524020589"', '3 "GUARANHOB"', '4 "25/09/1975"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007972/hipotese.txt
# 19781001735
# 72720270
# ARACAJI
# 20/11/1972
# GUILHERME NUNES NERIS
# PROIBIDO PLASTIFICAR
# ['0 "19781001735"', '1 "72720270"', '3 "ARACAJI"', '4 "20/11/1972"', '5 "GUILHERME NUNES NERIS"', '6 "PROIBIDO PLASTIFICAR"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007973/hipotese.txt
# 50922343601
# 199704992
# CONSOLIDAÇÃO-MG
# 20/01/1998
# PB216451561
# ['0 "50922343601"', '1 "199704992"', '3 "CONSOLIDAÇÃO-MG"', '4 "20/01/1998"', '5 "PB216451561"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007974/hipotese.txt
# 75619663032
# SP726448047
# 996188425
# MARCO-CE
# 20/12/1953
# ZAVAREZ ZAVITO MOREIRA
# ['0 "75619663032"', '1 "SP726448047"', '2 "996188425"', '3 "MARCO-CE"', '4 "20/12/1953"', '5 "ZAVAREZ ZAVITO MOREIRA"']
# /content/drive/MyDrive/GPT/resultados_gpt_mini_back/00007975/hipotese.txt
# 630959554
# MS328943318
# 35945264883
# CAMAPUÀ-MS
# 28/12/1997
# USIZIMA VANTI
# A; K;
# ['0 "630959554"', '1 "MS328943318"', '2 "35945264883"', '3 "CAMAPUÀ-MS"', '4 "28/12/1997"', '5 "USIZIMA VANTI"', '6 "A; K;"']

# %% [markdown]
# # Find attributes in results

# %%
import json
import re
import os

# Function to extract the JSON from within the text file
def extract_json_from_txt(txt_content):
    json_match = re.search(r'\{.*\}', txt_content, re.DOTALL)
    if json_match:
        return json.loads(json_match.group())
    else:
        raise ValueError("Nenhum bloco JSON encontrado no arquivo")

# Function to loop through all txt files and identify attribute names in JSON
def find_unique_attributes_in_json(base_dir):
    unique_attributes = set()  # Use a set to ensure attributes are unique

    # Cycle through all subfolders and files in the base folder
    for folder_name in os.listdir(base_dir):
        folder_path = os.path.join(base_dir, folder_name)

        if os.path.isdir(folder_path):
            for file_name in os.listdir(folder_path):
                if file_name.endswith('.txt'):
                    file_path = os.path.join(folder_path, file_name)

                    with open(file_path, 'r', encoding='utf-8') as file:
                        txt_content = file.read()

                    try:
                        # Extract JSON and get attributes (keys)
                        data = extract_json_from_txt(txt_content)
                        unique_attributes.update(data.keys())
                    except ValueError as e:
                        print(f"Error processing file {file_path}: {e}")

    return unique_attributes

input_base_dir = '/content/drive/MyDrive/GPT/resultados_gpt_back'

# Identify all unique attributes
unique_attributes = find_unique_attributes_in_json(input_base_dir)

# Display the names of unique attributes found
print("Unique attributes found in JSON:")
for attribute in sorted(unique_attributes):
    print(attribute)
# Out:
# Unique attributes found in JSON:
# assinatura emissor
# assinatura_emissor
# codigo
# código
# data emissão
# data_emissao
# data_emissão
# local
# numero
# numero_lateral
# número
# número lateral
# número_lateral
# observacoes
# observações
