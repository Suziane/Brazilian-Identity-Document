# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# *English below*
#
# ## Regras de Validação (PT)
#
# 1. **Número com mais dígitos (somente números)**
#    - Deve conter **apenas dígitos** (`text.isdigit()`).
#    - Deve ser o texto numérico com **mais dígitos** entre os candidatos.
#
# 2. **Alfanumérico (letras e números)**
#    - Deve conter **ao menos uma letra** e **ao menos um número**.
#    - Exemplo: `"A123456"`, `"12AB34"`.
#
# 3. **Número com menos dígitos (somente números)**
#    - Deve conter **apenas dígitos** (`text.isdigit()`).
#    - Deve ser o texto numérico com **menos dígitos** entre os candidatos restantes (após selecionar o da linha 2).
#
# 4. **LOCAL**
#    - Deve conter um **hífen (`-`)**.
#    - **Não** deve conter `"DETRAN"`.
#    - **Não** deve conter dígitos.
#
# 5. **DATA EMISSÃO**
#    - Deve estar no formato `dd/mm/aaaa`.
#    - Expressão regular: `\d{2}/\d{2}/\d{4}`.
#
# 6. **ASSINATURA DO EMISSOR**
#    - Deve estar **abaixo da metade da imagem** (`y > image_height // 2`).
#    - Deve conter **apenas letras** (sem dígitos ou hífens).
#    - Pode conter espaços.
#
# 7. **OBSERVAÇÕES**
#    - Deve estar **acima da metade da imagem** (`y <= image_height // 2`).
#
# 8. **Candidato mais próximo**
#    - Se nenhum valor válido for encontrado para os campos anteriores, selecionar o **mais próximo** com base na menor **distância euclidiana** ao campo de referência.
#
# ---
#
# ## Validation Rules (EN)
#
# 1. **Number with most digits (only numbers)**
#    - Must contain **only digits** (`text.isdigit()`).
#    - Should be the numeric text with the **most digits** among candidates.
#
# 2. **Alphanumeric (letters and numbers)**
#    - Must contain **at least one letter** and **at least one digit**.
#    - Example: `"A123456"`, `"12AB34"`.
#
# 3. **Number with fewer digits (only numbers)**
#    - Must contain **only digits** (`text.isdigit()`).
#    - Should be the numeric text with the **fewest digits** among remaining candidates (after picking line 2).
#
# 4. **LOCAL**
#    - Must contain a **hyphen (`-`)**.
#    - **Must not** contain `"DETRAN"`.
#    - **Must not** contain digits.
#
# 5. **DATA EMISSÃO (ISSUE DATE)**
#    - Must follow the format `dd/mm/yyyy`.
#    - Regex: `\d{2}/\d{2}/\d{4}`.
#
# 6. **ASSINATURA DO EMISSOR (ISSUER'S SIGNATURE)**
#    - Must be **below half the image** (`y > image_height // 2`).
#    - Must contain **only letters** (no digits or hyphens).
#    - Can include spaces.
#
# 7. **OBSERVAÇÕES (OBSERVATIONS)**
#    - Must be **above half the image** (`y <= image_height // 2`).
#
# 8. **Closest candidate**
#    - If no valid value is found for previous fields, select the **closest** one based on the **shortest Euclidean distance** to the reference field.

# %%
import math
import os
import re

label_list = [
    'LOCAL', 'DATA EMISSÃO', 'ASSINATURA DO EMISSOR', 'OBSERVAÇÕES'
]

def convert_to_tuples(conteudo):
    boxes = []
    lines = conteudo.strip().split('\n')

    for line in lines[1:]:
        values = line.split(', ')
        if line.startswith('['):
            parts = line.replace('[', '').replace(']', '').split(', ')
            x = int(parts[0])
            y = int(parts[1])
            width = int(parts[2]) - x
            height = int(parts[3]) - y
            transcription = parts[-1]
            boxes.append((x, y, width, height, transcription))

        else:
            if len(values) == 5:
                x = int(values[0])
                y = int(values[1])
                width = int(values[2])
                height = int(values[3])
                transcription = values[4]
                boxes.append((x, y, width, height, transcription))

    return boxes

def validate_transcription(label, transcription, width, height, y, image_height):
    transcription = transcription.strip()

    if label == 'LOCAL':
        return  '-' in transcription and 'DETRAN' not in transcription and not any(char.isdigit() for char in transcription)

    elif label == 'DATA EMISSÃO':
        return bool(re.fullmatch(r'\d{2}/\d{2}/\d{4}', transcription))

    elif label == 'ASSINATURA DO EMISSOR':
        return (
            y > image_height // 2
            and transcription.replace(" ", "").isalpha()
            and '-' not in transcription
            and not any(char.isdigit() for char in transcription)
        )

    elif label == 'OBSERVAÇÕES':
        return y <= image_height // 2

    return True

def calculate_distance(box1, box2):
    x1, y1 = box1[0], box1[1]
    x2, y2 = box2[0], box2[1]
    return math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

def sort_by_label(label_list, boxes):
    result = []
    added_transcriptions = set()
    added_labels = set()

    if not boxes:
        return result

    image_height = max([y + h for (_, y, _, h, _) in boxes])

    for label in label_list:
        box_label = next((box for box in boxes if box[4] == label and label not in added_labels), None)
        if box_label:
            added_labels.add(label)

            candidates = [
                box for box in boxes
                if box[4] not in label_list
                and box[4] not in added_transcriptions
                and validate_transcription(label, box[4], box[2], box[3], box[1], image_height)
            ]

            if label == 'ASSINATURA DO EMISSOR':
                candidates = sorted(candidates, key=lambda b: b[1])
                result.append(box_label)
                for c in candidates:
                    result.append(c)
                    added_transcriptions.add(c[4])

            elif label == 'OBSERVAÇÕES':
                candidates = sorted(candidates, key=lambda b: (b[1], b[0]))
                result.append(box_label)
                for c in candidates:
                    result.append(c)
                    added_transcriptions.add(c[4])

            else:
                if candidates:
                    closest = min(candidates, key=lambda b: calculate_distance(box_label, b))
                    result.append(box_label)
                    result.append(closest)
                    added_transcriptions.add(closest[4])
                else:
                    result.append(box_label)

    return result

def save_sorted_to_file(new_content, file_name):
    boxes = convert_to_tuples(new_content)
    ordered_result = sort_by_label(label_list, boxes)
    new_folder = '/content/drive/MyDrive/news_gt_back'
    if not os.path.exists(new_folder):
        os.makedirs(new_folder)

    file_name_output = os.path.join(new_folder, f'{os.path.splitext(os.path.basename(file_name))[0]}.txt')

    alphanum_box = None
    digit_boxes = []

    for box in boxes:
        x, y, width, height, transcription = box
        text = transcription.strip()

        if text.isdigit():
            digit_boxes.append((len(text), box))
        elif any(c.isalpha() for c in text) and any(c.isdigit() for c in text):
            if not alphanum_box:
                alphanum_box = box

    digit_boxes = sorted(digit_boxes, key=lambda x: x[0], reverse=True)
    only_digits_more = digit_boxes[0][1] if len(digit_boxes) > 0 else None
    only_digits_less = digit_boxes[1][1] if len(digit_boxes) > 1 else None

    for b in [only_digits_more, alphanum_box, only_digits_less]:
        if b in ordered_result:
            ordered_result.remove(b)

    final_result = []
    if only_digits_more:
        final_result.append(only_digits_more)
    if alphanum_box:
        final_result.append(alphanum_box)
    if only_digits_less:
        final_result.append(only_digits_less)

    final_result.extend(ordered_result)

    with open(file_name_output, 'w') as f:
        for box in final_result:
            x, y, width, height, transcription = box
            f.write(f"{x}, {y}, {width}, {height}, {transcription}\n")

    print(f"File saved in: {file_name_output}")



def process_folder():
    folder = '/content/drive/MyDrive/BD/BID Dataset/CNH_Verso'
    txt_files = [f for f in os.listdir(folder) if f.endswith('.txt')]

    for file in txt_files:
        file_path = os.path.join(folder, file)

        with open(file_path, 'r', encoding='latin1') as f:
            content = f.readlines()

        ignore_list = ['PROIBIDO PLASTIFICAR', 'ASSINATURA DO PORTADOR', 'DEPARTAMENTO NACIONAL DE TRÂNSITO', 'DETRAN']
        filtered_lines = [line for line in content if not any(ignore in line for ignore in ignore_list)]
        new_content = ''.join(filtered_lines)

        save_sorted_to_file(new_content, file_path)

process_folder()
# Out:
# File saved in: /content/drive/MyDrive/news_gt_back/00010519_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010528_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010520_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010522_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010525_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010523_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010534_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010533_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010530_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010532_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010531_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010535_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010541_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010542_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010539_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010537_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010540_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010538_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010536_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010546_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010553_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010543_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010550_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010551_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010549_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010547_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010544_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010545_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010548_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010552_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010560_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010556_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010557_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010559_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010563_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010554_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010562_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010558_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010564_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010555_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010561_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010565_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010572_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010574_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010567_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010569_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010571_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010573_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010568_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010566_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010570_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010575_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010579_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010581_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010583_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010576_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010582_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010578_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010587_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010585_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010580_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010584_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010577_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010586_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010595_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010588_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010596_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010599_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010594_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010589_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010593_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010592_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010591_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010590_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010598_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010597_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010600_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010604_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010608_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010607_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010602_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010606_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010609_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010601_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010605_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010603_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010617_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010619_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010613_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010612_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010611_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010616_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010610_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010615_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010618_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010614_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010627_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010629_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010628_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010624_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010625_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010621_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010622_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010620_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010626_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010623_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010631_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010634_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010633_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010632_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010630_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010635_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010636_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010637_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010641_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010643_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010640_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010642_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010638_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010639_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010648_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010647_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010645_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010644_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010653_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010651_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010646_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010649_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010652_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010650_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010654_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010662_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010664_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010661_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010663_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010656_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010658_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010655_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010659_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010660_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010657_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010667_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010673_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010665_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010671_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010666_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010674_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010672_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010675_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010668_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010670_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010669_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010683_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010680_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010684_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010679_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010682_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010681_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010678_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010677_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010676_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010686_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010687_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010689_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010690_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010693_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010695_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010691_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010685_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010694_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010688_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010692_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010699_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010702_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010697_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010698_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010700_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010704_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010703_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010701_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010696_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010706_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010707_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010709_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010712_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010705_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010708_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010711_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010713_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010710_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010718_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010723_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010721_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010716_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010715_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010714_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010717_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010722_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010724_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010720_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010719_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010732_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010733_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010727_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010725_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010731_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010736_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010735_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010730_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010726_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010729_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010734_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010728_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010737_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010741_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010743_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010744_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010746_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010745_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010742_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010747_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010748_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010740_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010739_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010738_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010750_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010758_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010752_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010756_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010751_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010753_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010754_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010749_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010757_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010755_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010759_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010767_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010770_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010763_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010760_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010771_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010769_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010765_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010766_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010764_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010762_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010761_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010768_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010778_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010774_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010779_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010773_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010775_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010772_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010777_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010780_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010776_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010782_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010781_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010795_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010793_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010784_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010783_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010790_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010791_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010794_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010787_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010785_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010786_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010789_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010792_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010788_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010796_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010802_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010799_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010798_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010801_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010804_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010803_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010800_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010797_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010809_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010808_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010805_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010806_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010810_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010807_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010811_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010818_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010820_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010817_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010816_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010819_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010814_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010813_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010815_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010812_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010822_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010824_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010823_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010821_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010825_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010830_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010826_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010828_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010827_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010829_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010831_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010835_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010840_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010833_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010837_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010838_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010842_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010836_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010834_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010839_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010832_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010841_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010844_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010853_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010851_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010843_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010848_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010850_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010849_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010845_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010855_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010847_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010854_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010852_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010846_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010194_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010188_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010186_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010187_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010185_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010191_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010199_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010206_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010201_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010207_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010195_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010198_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010196_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010197_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010200_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010204_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010205_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010203_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010202_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010218_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010213_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010216_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010212_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010217_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010214_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010210_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010208_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010211_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010215_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010209_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010222_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010224_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010219_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010226_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010231_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010228_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010225_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010227_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010229_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010220_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010221_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010230_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010223_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010242_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010237_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010240_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010232_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010239_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010233_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010234_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010243_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010241_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010236_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010238_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010235_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010253_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010254_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010245_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010246_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010247_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010244_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010252_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010255_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010248_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010256_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010249_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010251_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010250_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010260_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010264_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010261_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010267_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010266_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010258_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010257_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010262_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010263_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010259_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010265_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010276_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010268_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010269_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010272_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010278_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010274_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010271_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010279_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010273_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010270_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010277_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010275_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010281_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010283_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010284_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010282_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010280_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010288_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010287_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010292_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010290_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010286_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010285_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010289_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010291_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010293_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010294_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010297_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010295_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010301_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010300_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010305_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010302_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010306_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010303_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010299_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010304_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010296_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010298_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010307_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010316_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010317_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010311_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010310_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010312_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010315_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010309_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010314_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010308_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010313_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010329_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010322_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010323_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010319_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010324_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010321_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010327_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010325_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010320_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010326_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010318_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010328_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010339_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010331_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010338_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010336_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010330_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010332_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010333_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010337_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010335_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010334_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010348_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010347_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010351_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010341_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010344_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010345_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010346_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010340_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010350_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010343_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010349_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010342_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010360_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010363_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010355_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010352_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010354_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010359_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010358_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010362_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010364_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010357_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010361_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010353_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010356_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010369_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010370_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010367_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010368_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010372_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010373_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010371_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010365_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010374_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010366_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010380_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010377_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010379_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010382_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010376_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010383_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010381_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010375_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010386_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010378_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010385_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010384_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010393_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010395_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010392_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010391_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010390_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010389_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010394_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010387_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010388_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010397_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010396_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010398_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010400_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010399_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010404_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010407_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010401_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010402_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010403_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010406_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010405_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010408_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010416_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010418_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010411_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010415_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010409_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010410_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010414_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010417_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010412_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010413_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010419_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010421_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010423_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010428_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010426_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010420_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010424_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010429_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010422_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010427_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010425_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010439_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010438_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010435_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010430_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010434_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010432_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010437_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010433_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010436_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010431_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010442_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010440_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010444_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010443_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010446_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010441_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010447_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010445_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010448_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010451_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010452_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010449_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010458_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010459_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010455_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010456_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010450_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010457_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010454_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010453_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010464_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010461_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010462_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010463_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010468_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010466_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010465_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010467_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010460_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010470_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010469_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010472_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010473_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010478_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010471_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010476_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010475_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010474_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010477_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010482_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010488_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010479_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010487_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010481_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010485_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010486_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010483_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010484_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010480_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010499_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010495_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010496_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010497_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010494_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010498_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010500_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010493_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010492_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010491_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010489_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010490_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010502_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010509_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010506_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010510_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010508_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010503_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010504_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010501_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010507_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010505_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010513_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010512_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010517_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010511_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010516_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010514_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010518_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010515_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010521_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010527_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010524_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010529_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00010526_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009855_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009863_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009860_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009864_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009861_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009857_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009862_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009858_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00009859_gt_ocr.txt
# ...
# File saved in: /content/drive/MyDrive/news_gt_back/00007297_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007291_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007303_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007300_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007290_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007305_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007296_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007301_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007293_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007295_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007304_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007298_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007312_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007311_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007324_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007316_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007315_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007326_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007318_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007319_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007320_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007308_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007325_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007310_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007323_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007317_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007309_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007321_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007322_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007314_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007313_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007341_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007333_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007335_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007337_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007330_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007340_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007342_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007331_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007328_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007334_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007339_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007336_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007329_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007343_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007345_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007327_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007332_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007338_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007344_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007351_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007347_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007352_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007358_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007349_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007360_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007355_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007353_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007357_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007346_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007361_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007348_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007354_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007350_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007356_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007359_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007367_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007369_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007372_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007371_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007374_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007362_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007368_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007373_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007370_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007364_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007365_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007363_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007366_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007379_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007376_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007389_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007375_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007382_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007388_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007381_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007383_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007384_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007377_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007386_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007380_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007378_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007387_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007385_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007403_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007404_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007390_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007400_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007402_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007398_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007405_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007394_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007396_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007395_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007393_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007401_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007392_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007397_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007391_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007399_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007412_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007416_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007406_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007414_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007408_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007417_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007411_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007409_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007419_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007413_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007415_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007410_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007418_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007407_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007421_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007428_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007432_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007426_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007424_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007430_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007423_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007431_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007427_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007420_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007425_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007433_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007422_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007429_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007443_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007436_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007447_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007445_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007434_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007438_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007439_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007442_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007435_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007440_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007446_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007437_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007441_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007444_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007456_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007449_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007460_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007457_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007448_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007453_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007458_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007454_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007452_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007459_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007451_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007450_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007455_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007461_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007468_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007466_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007470_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007464_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007471_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007462_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007465_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007463_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007469_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007467_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007472_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007476_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007475_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007479_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007484_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007482_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007478_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007486_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007477_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007481_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007487_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007485_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007483_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007474_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007473_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007480_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007501_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007499_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007497_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007488_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007496_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007491_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007490_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007500_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007495_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007498_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007493_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007494_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007492_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007489_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007515_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007512_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007508_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007513_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007504_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007507_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007510_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007506_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007511_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007514_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007502_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007503_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007509_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007505_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007516_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007521_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007528_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007523_gt_ocr.txt
# File saved in: /content/drive/MyDrive/news_gt_back/00007524_gt_ocr.txt

# %%
import os

folder_path = '/content/drive/MyDrive/news_gt_back/'
txt_files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]

print(f"Total de arquivos .txt: {len(txt_files)}")
# Out:
# Total de arquivos .txt: 3600
